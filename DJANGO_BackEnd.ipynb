# %% [raw]
# [086] Overview of Django
#
#     - Documentation of Django
#     - clone projects
#         - social logins
#         - authorization
#         - deployment
#         - security
#
#
# [115] Overview of Django (web framework)
#     - Map a request from a user to the code that's meant to handle it and create requested html dynamically. Using templates we can inject calculated values or information from the database into an html page to show to user. Connect front end and backend.
#     -  DJANGO HAS A VERY GOOD TUTORIAL POLLING WEB APP !!!!!!!
#     - venv  in conda  tutorial
#         conda.io/docs/using/envs.html
#
#
# [116] First Django Project (different from Django application)
#     - Run a Django project, a server locally and see it in browser.
#     - ESSENTIAL STEPS HERE!!!!!!
#     - After installing virtual enviroment and django
#     #######
#     1. conda create --name myDjangoEnv django
#     ############
#     2. conda info --envs   (to see enviroments)
#     #####################
#     3. activate myDjangoEnv
#     ##################################################
#     4. Create first project with:
#     django-admin startproject first_Django_project
#     ###################################################
#     5. python manage.py runserver   --> 127.0.0.1:8000
#     ###########################
#     - migrations have to do with databases and how to connect them to Django
#
# [117] Django Application
#     - start first app  (within our Django project we create a Django application)
#     #########################################
#      6. python manage.py startapp first_app
#     ###################################
#     - Define what each file does
#     - !!!!!!! STEPS FOR VIEW !!!!!!
#     - Create Hello World Applications
#
#
# [118-119] Django Application Creations and Project + Solutions
#     - Create project: django-admin startproject secondProject
#     - Create application inside project:
#         - cd secondProject
#         - python manage.py startapp appTwo
#     - Create a view: Go to views.py
#         from django.http import HttpResponse
#         def index(request):
#             return HttpResponse("<em> 2nd Project </em>")
#     - Link view to url: Got to url.py
#         from appTwo import views
#         urlpatters = [ url(r'^$', views.index, name="index"), ...]
#     -  Edit settings.py under secondProject to let the project know that appTwo exists:
#         Go to INSTALLED_APPS and add 'appTwo'
#     -  Run server:  python manage.py runserver
#
#
# REGULAR EXPRESSION
# ^admin/  means that it should start with admin/
# admin/$  means that it should end with admin/
# ^$  means the homepage  www.fcb.com/  nothing more. No www.fcb.com/admin/
#
#
# [120]  URL Mappings

# %% [markdown]
# The Net Ninja
# https://www.youtube.com/watch?v=n-FTlQ7Djqc&list=PL4cUxeGkcC9ib4HsrXEYpQnTOTZE1x0uc&ab_channel=TheNetNinja&t=1s

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 1. User Authentication, routing,
#     - Django documentation: docs.djangoproject.com/en/1.11/

# %%
### mock data
    - Add more values than expected
    - Testing error handling
blog.scottlogic.com/2016/02/08/data-mocking.html
