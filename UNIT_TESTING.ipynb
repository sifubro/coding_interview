# %% [markdown]
# - https://www.youtube.com/watch?v=6tNS--WetLI&list=PL-osiE80TeTt2d9bfVyTiXJA-UTHn6WwU&index=57
#
# -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### https://docs.python.org/2/using/cmdline.html#cmdoption-m
# ### https://docs.python.org/3/library/unittest.html#command-line-interface

# %% [raw]
# The python -m flag means module. Some modules (libraries) have main entry points, and the -m flag can be used to run them on the command line.
#
# Example
#
# Python unittest module has a main entry point.
#
# python -m unittest test_module.TestClas

# %% [markdown]
# ## MOCKING
#
# - for accessing things that change out of your control (urls return etc..)

# %% [markdown]
# ## Unittest
#
# https://www.youtube.com/watch?v=HKTyOUx9Wf4&ab_channel=CodeSports

# %%
import unittest

# %% [markdown]
# ## pytest
#
# https://www.youtube.com/watch?v=_QtM7QGuj1A&list=PLS1QulWo1RIaNFUz4zrztWlCJgkpXht-H&ab_channel=ProgrammingKnowledge
#
# https://gist.github.com/pknowledge

# %% [raw]
# pip install pytest
# pytest -h
#
# pytest test_math_func.py -v
# #or
# py.test
#
# #run only one test
# pytest test_math_func.py::test_add -v

# %% [raw]
# #-k for matching expressions. Run tests that contain "add" keyword in their names
# pytest -v -k "add"
#
# # run tests that contain "add" or "string" keywords
# pytest -v -k "add or string"
#
# # run tests that contain "add" and "string" keywords
# pytest -v -k "add and string"

# %% [raw]
# -m for mark expression
#
# pytest -v -m number   --> run all tests which have the number mark in the decorator

# %% [raw]
# -x exit first if failure occurs exit (hence don't run all of them)
#
# pytest -v -x
#
# #other flags
# --tb=no    --> No stack trace
# --maxfail=2   --> Exit after 2 failures
#
# # skip decorator
# @pytest.mark.skip(reason="do not run number add test")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# # skipif decorator for condition
# # skip if python version <3.3
# @pytest.mark.skipif(sys.version_info< (3, 3) , reason="do not run number add test")

# %% [raw]
# #-s option  --> print any output with print function inside the tests
#
# pytest -v -s

# %% [raw]
# #-q quite mode option

# %% [raw]
# # parameterize decorator to test the same function with different type of values instead of

# %% [raw]
# # fixtures with pytest
