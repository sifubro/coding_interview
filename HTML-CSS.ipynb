# %% [markdown]
# # (1)
# ### https://www.youtube.com/watch?v=wXUhTZpF_HQ&ab_channel=DaniKrossing
# ### https://www.youtube.com/watch?v=TKYsuU86-DQ&list=PL0eyrZgxdwhwNC5ppZo_dYGVjerQY3xYU&ab_channel=DaniKrossing
# ###  https://www.youtube.com/c/TheCharmefis/playlists
#
# # (2)
# #### https://www.youtube.com/watch?v=9Lpxzhzjy9w&ab_channel=TheNetNinja
#
#
# # (5)
# #### https://developer.mozilla.org/en-US/docs/Web/HTML/Element
#
#
# https://www.w3schools.com/html/html_elements.asp

# %% [markdown]
# ## (1) DaniKrossing HTML
#
# #### https://www.youtube.com/watch?v=1YO_5jXC-bo&list=PL0eyrZgxdwhwNC5ppZo_dYGVjerQY3xYU&index=6&ab_channel=DaniKrossing
#
#
# - 1) TO SEE later (intro)
#     - html, head tag, body,
# - 2) TO SEE later (intro)
# - 3) Attributes
#     - charset in meta tags
#     - <p title="this is some website content!" style="color:red;"> Hello world </p>
#       With this you get a popup when you hover the mouse over Hello World. In this example, title is an attribute. Also style is an attribute to write CSS code inside this tag.
#
# - 4) Text in webpage <p>, <h1>,
#     - **<section>** tag --> used to describe that we have content similar to each other inside these tags
#     - **<article>** tag --> This means that content inside this tag are related to each other. It is a semantic code that defines where the article is on a page. It doesn't really do anything discernible. It is meant to be used by text reading software and search engines to define where the really important stuff is on the web page.
#     - What is the
#     - <br> to change line
#
# ### QUESTION: Difference between section, article and div tag. When to use one and when the other???
#
# - 5) DIVS (aka boxes)
#     - div can be split into multiple divs also
#     - What is <article> ??
# - 6) Include CSS in HTML.
#     - Directly through the "style" tag in <head> after <meta> and create CSS code in dictionary.
#     e.g. h2 {color:red; font-size: 70px; margin:0px; background-color:clue; text-align: center; }
#     - Directly in an html element:
#     e.g. <h2 style="color:red;" > This is a header styled </h2>
#     - Typically create a separate CSS file and link it inside the html file:
#     <link rel="stylesheet" href="path_to_style.css">
#     - for classes use .class1 { }
#     - div h2 {} --> change the h2 tag inside the div
#     -
# - 7) Create comments
# - 8) Classes and IDs
#     - target a specific element to style it. Without them we would style every <p>. We may want to target specific <p> elements though! That's why we use classes and Ids.
#     e.g. Below Header1 and Header2 will get same styling from .cls1{} in CSS but not the Header3!!
#     <h2 class="cls1"> Header1 </h2>
#     <h2 class="cls1"> Header2 </h2>
#     <h2> Header3 </h2>
#
#     - container and classes
#     <div class="index-div1">
#         <p> Welcome </p>
#         <h1> Header </h1>
#     You can style only the paragraph in div as
#         .index-div1  p  {color:red;}
#
#     - IDs: IS UNIQUE per html element!! (in contrast to classes which may be shared!) Moreover you cannot have 2 ids (separated with space) as in classes.
#         <h2 class="cls1" id="ID1"> Title </h2>
#         Then in CSS style  #ID1 { }
#
#     - ESSENTIAL DIFFERENCE IDS-CLASSES: LINKING TO CERTAIN SECTIONS You can use IDs to get redirected in a specific area of a page when clicking a button for example 7:40. This cannot be done with classes!!!!
#         example:
#         <a href="#index-courses"> Click to fo to Courses </a>
#         .... and later on in page
#         <div id="index-courses">
#             <p> Courses </p>
#         </div>
#
#     - Also JavaScripts requires to use IDs for certain things.
#     - Question: Create 2 classes in html
#
# - 9)

# %% [markdown]
# ## The NET NinJA

# %%
## 2

# -7) Jumbotrons
    - Container centralized the text!

# %%
https://developer.mozilla.org/en-US/docs/Web/CSS/
    
www.w3schools.com/css/css_intro.asp

# %% [markdown]
# ## Portilla

# %% [raw]
# **[000] .**
#
# **[007] head and body and how to comment code.**
#     - head contains **metadata** and tab **title** at top left. The head can be used to link html with other types of files like CSS
#     - body contina the actual content
#     - comment with <!-- commnets... -->  OR ctrl+/
#
# **[008] Heading and paragraph tags, how to bold and italics & References**
#     - bold with 'b' or 'strong'
#     - italics with 'i' or 'em'
#     - References:
#         - https://developer.mozilla.org/en-US/docs/Web/HTML/Element
#         - https://www.w3schools.com/html/html_elements.asp
#
# **[009] Lists.**
#     - ordered list with 'ol'
#     - un-ordered lists with 'ul'
#         - add list elements with 'li'
#
# **[010] div and span**
#     - div: tag togeether group of elements and generate containers
#     <div class="groupone">
#         <h1>dsds</h1>
#         <p> fdsfdsf  <span> dfsdfs </span> </p>
#     </div>
#
#     - span is like div tag by applies effect in-line
#
# **[011-012-013] Attributes: adds links or referencing img hence adding more info.**
#     - Add image with <img src="my_img.png", alt="Text for broken link"> self-closing tag
#     - Resize image later on ***[???]***
#     - Reference another webpage html file with <a href = "www.facebook.com"> Text which is clicable link</a>
#     - **Clickable image to reference website**:
#       You can combine the previous two and say
#       <a href= "www.fcb.com">
#             <img  src="my_img.png" alt="Text for broken link">
#       </a>
#
#
# **[015-016-017] Tables.**
#     - <table border="1">  --> specify border also
#         <thead> header row
#             <th> <img src="" alt="" ></th> 1st column name
#             <th> </th> 2nd column name  etc.
#         <tr>  1st row
#             <td> </td> 1st row 1st column
#             <td> </td> 1st row 2nd column etc
#         </tr>
#         <tr>  2nd row
#             <td> <img src="" alt="" ></td> 2nd row 1st column
#             <td> </td> 2nd row 2nd column etc
#         </tr>
#      - You can put images in a cell of the table like shown above
#
# **[018] Forms<input> tags from user. Here input is <input> "text", "email", "password", "submit"**
#     - https://www.w3schools.com/html/html_form_input_types.asp
#     - https://developer.mozilla.org/en-US/docs/Web/HTML/  --> input tags
#     - Syntax:
#       <form class="" action= "" method="post" (or get)>
#           <h1> dsadsad </h1>
#           <input type = "text" name ="" value ="default value" >
#           (use **placeholder** = "default value" better !!)
#           (use **required** for field that are essential to fill)
#           (type can be "email", "password", "submit", "color")
#       </form>
#
# **[019] Actions (upon clicking button) and Label a forms.**
#       - **ACTION**
#       <form class="" action= "www.fcb.com" method="post" (or get)>
#           <h1> dsadsad </h1>
#           <input type = "email" name ="useremail" value ="" >
#           <input type = "submit" name ="" value ="Submit" >
#           (When clicking Submit button you will be re-directed to fcb!!)
#           (This happens along with the input!! See the address in top!!)
#       </form>
#       - **LABELS**
#       (Same line of text and boxes!)
#        Bad way:
#          <form>
#             <label>
#              Text
#              <input type ="text" name = "" value ="">
#             </label>
#          </form>
#        Good way using **label for** and **id**
#             <label for "userinput"> Enter input </label>
#             <input id="userinput" type="text" name="" value="Hello">
#       - **id** uniquelly identifies a tag (hence we can style them)!!!
#
# **[020-021-022] Radio button, Dropdown menu, Text Area Input**
#     - Radio
#     <form method="get">
#         <label for="ON"> ON SWITCH</label>
#         <input id="ON" type="radio" name="ON-OFF" value=1>
#
#         # NOTICE THE SAME NAME!
#
#         <label for="OFF"> OFF SWITCH</label>
#         <input id="OFF" type="radio" name="ON-OFF" value=0>
#
#     - Dropdown
#       <select name="stars">
#         <option value=3>"Great"</option>
#         <option value=2>"Okay"</option>
#         <option value=1>"Bad"</option>
#       </select>
#
#     - textbox (see AtoM)
#     - see [027] for checkbox at 03:00
#
#     - ASSESSEMENT:
#         - **Link signup button with another page!!**
#
# **[024] link HTML to CSS**
#     - In head create
#       <link rel="stylesheet" hred="style_my_html.css">
#     - STOP HERE
#
# **[026] Style background colors & imgs, borders, span colors in CSS**
#     - uses dictionaries for each tag
#
# **[027] selectors to style single elements (id) or group of elements (class)**
#     - Create <div class="FirstClass"> </div>
#     -<div class="FirstClass"> </div>
#     (If you style div it will affect both!)
#     - In css do .FirstClass{} to only style the class and not all divs
#
#     - <p id='myID1'> fsdfsdfsf <\p>
#     - To style the id tag use #myID1{} in CSS
#
#     - *{} styles everything on the page and overwrites all previous except IDs
#
#     - www.w3schools.com/cssref/css_selectors.asp reference
#
#     - adjacent-siblings (elements tha are next to each other)
#     Select all unordered list items that are next to h3 heading
#     h3 + ul{}
#
#     - descendants
#     To grab all anchor tags that are inside a list
#     li a{}
#
#     - Affect actributes
#     Grab any anchor tag inside list with a particual ref
#     li a[href="www.fcb.com"]{ dicto of styles }
#
#
# #################################################################
# #### Do less words!!
# #########################
#
#
# **[028] Google Chrome Inspector**
#
# **[029] Specificity : Hierarchy of CSS styling. Which styles on tags affect/overwrite others**
#     - id  > class > general tag call for 'li'
#     - see www.designhack.net  what-the-heck-is-css-specificity
#
# **[030-31] ASSESSMENT with TASKS!! **
#     - use google colorpicker to pick HEX colour
#     - css visisted to change the color of link we have visited
#
#
# **[033] Fonts size, style, weights, allignment, in different operating systems**
#     - EM values to dynamically size things in respect with each other
#      1em =16px for e.g. in
#      if you define
#      body{
#          font-size:20px
#      }
#      then 1em=20px
#      font-style:italic
#      font-weight:bold
#      text-align:center
#      text-decoration
#      Later in Bootstrap we will see how it works on mobile devices.
#
#
# **[034] What fonts work with each OS**
#     Fonts on Windows:
#     https://en.wikipedia.org/wiki/List_of_typefaces_included_with_Microsoft_Windows
#     Fonts on Macs:
#     https://en.wikipedia.org/wiki/List_of_typefaces_included_with_macOSfon
#     General Font Information:
#     http://www.cssfontstack.com/
#
#
#     To download fonts:
#     fonts.google.com
#     https://fontlibrary.org/en
#
#
# **[035] CSS Box Model**
#     - Content, Padding, Border, Margin
#     - left, right, top, bottom
#     -
#
#
# **[036] Spectrum Project**
#     - boxes and color palet
#     - coolors.co
