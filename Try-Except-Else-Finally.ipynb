# %% [markdown]
# - https://www.youtube.com/watch?v=NIWwJbo-9_8

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - **else** is code that executes if the try clause doesn't raise an Exception
#
# - **finally** runs always (regardless of if we hit exception or not) Useful to close down databases etc..

# %% [markdown]
# ![image.png](attachment:image.png)
