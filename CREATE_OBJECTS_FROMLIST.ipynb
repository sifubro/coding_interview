# %% [markdown]
# ### https://stackoverflow.com/questions/42139625/python-creating-objects-by-referring-the-object-name-through-variable-creating
#
# ### https://www.programiz.com/python-programming/methods/built-in/globals
#
# ### https://thepythonguru.com/python-builtin-functions/globals/
#
# ### https://thepythonguru.com/python-builtin-functions/locals/

# %%
a = 1
b = 2

def my_func(x):
    'print the argument'
    c = 3
    d = 4
    print(x)

# %%
my_func('hello')
# Out:
# hello

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "a = 1\nb = 2\n\ndef my_func(x):\n    'print the argument'\n    c = 3\n    d = 4\n    print(x)",
#   "my_func('hello')",
#   'globals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\30694\\Desktop\\ML-STATS\\ML-AI\\Theo_ML'],
#  'In': ['',
#   "a = 1\nb = 2\n\ndef my_func(x):\n    'print the argument'\n    c = 3\n    d = 4\n    print(x)",
#   "my_func('hello')",
#   'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001C6A80E5488>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1c6a81222c8>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1c6a81222c8>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': "my_func('hello')",
#  '_ii': "a = 1\nb = 2\n\ndef my_func(x):\n    'print the argument'\n    c = 3\n    d = 4\n    print(x)",
#  '_iii': '',
#  '_i1': "a = 1\nb = 2\n\ndef my_func(x):\n    'print the argument'\n    c = 3\n    d = 4\n    print(x)",
#  'a': 1,
#  'b': 2,
#  'my_func': <function __main__.my_func(x)>,
#  '_i2': "my_func('hello')",
#  '_i3': 'globals()'}

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "a = 1\nb = 2\n\ndef my_func(x):\n    'print the argument'\n    c = 3\n    d = 4\n    print(x)",
#   "my_func('hello')",
#   'globals()',
#   'locals()'],
#  '_oh': {3: {...}},
#  '_dh': ['C:\\Users\\30694\\Desktop\\ML-STATS\\ML-AI\\Theo_ML'],
#  'In': ['',
#   "a = 1\nb = 2\n\ndef my_func(x):\n    'print the argument'\n    c = 3\n    d = 4\n    print(x)",
#   "my_func('hello')",
#   'globals()',
#   'locals()'],
#  'Out': {3: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001C6A80E5488>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1c6a81222c8>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1c6a81222c8>,
#  '_': {...},
#  '__': '',
#  '___': '',
#  '_i': 'globals()',
#  '_ii': "my_func('hello')",
#  '_iii': "a = 1\nb = 2\n\ndef my_func(x):\n    'print the argument'\n    c = 3\n    d = 4\n    print(x)",
#  '_i1': "a = 1\nb = 2\n\ndef my_func(x):\n    'print the argument'\n    c = 3\n    d = 4\n    print(x)",
#  'a': 1,
#  'b': 2,
#  'my_func': <function __main__.my_func(x)>,
#  '_i2': "my_func('hello')",
#  '_i3': 'globals()',
#  '_3': {...},
#  '_i4': 'locals()'}

# %%
locals() == globals()
# Out:
# True

# %%
def foo():
    x = 30 # x and y are local variables
    y = 40

    print("locals() = {0}".format(locals()))
    print('*'*30)
    print('locals:')
    print(locals())
    #print('*'*30)
    #print('globals:')
    #print(globals())

# %%
foo()
# Out:
# locals() = {'x': 30, 'y': 40}
# ******************************
# locals:
# {'x': 30, 'y': 40}

# %%
type(foo)
# Out:
# function

# %%
dir(foo)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
import inspect
inspect.getmembers(foo)
# Out:
# [('__annotations__', {}),
#  ('__call__',
#   <method-wrapper '__call__' of function object at 0x000001C6A959B828>),
#  ('__class__', function),
#  ('__closure__', None),
#  ('__code__',
#   <code object foo at 0x000001C6A959B6F0, file "<ipython-input-16-9016d78fffb4>", line 1>),
#  ('__defaults__', None),
#  ('__delattr__',
#   <method-wrapper '__delattr__' of function object at 0x000001C6A959B828>),
#  ('__dict__', {}),
#  ('__dir__', <function function.__dir__()>),
#  ('__doc__', None),
#  ('__eq__',
#   <method-wrapper '__eq__' of function object at 0x000001C6A959B828>),
#  ('__format__', <function function.__format__(format_spec, /)>),
#  ('__ge__',
#   <method-wrapper '__ge__' of function object at 0x000001C6A959B828>),
#  ('__get__',
#   <method-wrapper '__get__' of function object at 0x000001C6A959B828>),
#  ('__getattribute__',
#   <method-wrapper '__getattribute__' of function object at 0x000001C6A959B828>),
#  ('__globals__',
#   {'__name__': '__main__',
#    '__doc__': 'Automatically created module for IPython interactive environment',
#    '__package__': None,
#    '__loader__': None,
#    '__spec__': None,
#    '__builtin__': <module 'builtins' (built-in)>,
#    '__builtins__': <module 'builtins' (built-in)>,
#    '_ih': ['',
#     "a = 1\nb = 2\n\ndef my_func(x):\n    'print the argument'\n    c = 3\n    d = 4\n    print(x)",
#     "my_func('hello')",
#     'globals()',
#     'locals()',
#     'print(globals())',
#     'from pprint import pprint\n\npprint(globals())',
#     'locals() == globals()',
#     'def foo():\n    x = 30 # x and y are local variables\n    y = 40\n\n    print("locals() = {0}".format(locals()))',
#     'foo()',
#     'def foo():\n    x = 30 # x and y are local variables\n    y = 40\n\n    print("locals() = {0}".format(locals()))\n    print(\'*\'*20)\n    print(locals())',
#     'foo()',
#     'def foo():\n    x = 30 # x and y are local variables\n    y = 40\n\n    print("locals() = {0}".format(locals()))\n    print(\'*\'*30)\n    print(locals())',
#     'foo()',
#     'def foo():\n    x = 30 # x and y are local variables\n    y = 40\n\n    print("locals() = {0}".format(locals()))\n    print(\'*\'*30)\n    print(\'locals:\')\n    print(locals())\n    print(\'*\'*30)\n    print(\'globals:\')\n    print(globals())',
#     'foo()',
#     'def foo():\n    x = 30 # x and y are local variables\n    y = 40\n\n    print("locals() = {0}".format(locals()))\n    print(\'*\'*30)\n    print(\'locals:\')\n    print(locals())\n    #print(\'*\'*30)\n    #print(\'globals:\')\n    #print(globals())',
#     'foo()',
#     'type(foo)',
#     'functio',
#     'function',
#     'dir(function)',
#     'dir(foo)',
#     'inspect.getmembers(foo)',
#     'import inspect\ninspect.getmembers(foo)'],
#    '_oh': {3: {...},
#     4: {...},
#     7: True,
#     18: function,
#     22: ['__annotations__',
#      '__call__',
#      '__class__',
#      '__closure__',
#      '__code__',
#      '__defaults__',
#      '__delattr__',
#      '__dict__',
#      '__dir__',
#      '__doc__',
#      '__eq__',
#      '__format__',
#      '__ge__',
#      '__get__',
#      '__getattribute__',
#      '__globals__',
#      '__gt__',
#      '__hash__',
#      '__init__',
#      '__init_subclass__',
#      '__kwdefaults__',
#      '__le__',
#      '__lt__',
#      '__module__',
#      '__name__',
#      '__ne__',
#      '__new__',
#      '__qualname__',
#      '__reduce__',
#      '__reduce_ex__',
#      '__repr__',
#      '__setattr__',
#      '__sizeof__',
#      '__str__',
#      '__subclasshook__']},
#    '_dh': ['C:\\Users\\30694\\Desktop\\ML-STATS\\ML-AI\\Theo_ML'],
#    'In': ['',
#     "a = 1\nb = 2\n\ndef my_func(x):\n    'print the argument'\n    c = 3\n    d = 4\n    print(x)",
#     "my_func('hello')",
#     'globals()',
#     'locals()',
#     'print(globals())',
#     'from pprint import pprint\n\npprint(globals())',
#     'locals() == globals()',
#     'def foo():\n    x = 30 # x and y are local variables\n    y = 40\n\n    print("locals() = {0}".format(locals()))',
#     'foo()',
#     'def foo():\n    x = 30 # x and y are local variables\n    y = 40\n\n    print("locals() = {0}".format(locals()))\n    print(\'*\'*20)\n    print(locals())',
#     'foo()',
#     'def foo():\n    x = 30 # x and y are local variables\n    y = 40\n\n    print("locals() = {0}".format(locals()))\n    print(\'*\'*30)\n    print(locals())',
#     'foo()',
#     'def foo():\n    x = 30 # x and y are local variables\n    y = 40\n\n    print("locals() = {0}".format(locals()))\n    print(\'*\'*30)\n    print(\'locals:\')\n    print(locals())\n    print(\'*\'*30)\n    print(\'globals:\')\n    print(globals())',
#     'foo()',
#     'def foo():\n    x = 30 # x and y are local variables\n    y = 40\n\n    print("locals() = {0}".format(locals()))\n    print(\'*\'*30)\n    print(\'locals:\')\n    print(locals())\n    #print(\'*\'*30)\n    #print(\'globals:\')\n    #print(globals())',
#     'foo()',
#     'type(foo)',
#     'functio',
#     'function',
#     'dir(function)',
#     'dir(foo)',
#     'inspect.getmembers(foo)',
#     'import inspect\ninspect.getmembers(foo)'],
#    'Out': {3: {...},
#     4: {...},
#     7: True,
#     18: function,
#     22: ['__annotations__',
#      '__call__',
#      '__class__',
#      '__closure__',
#      '__code__',
#      '__defaults__',
#      '__delattr__',
#      '__dict__',
#      '__dir__',
#      '__doc__',
#      '__eq__',
#      '__format__',
#      '__ge__',
#      '__get__',
#      '__getattribute__',
#      '__globals__',
#      '__gt__',
#      '__hash__',
#      '__init__',
#      '__init_subclass__',
#      '__kwdefaults__',
#      '__le__',
#      '__lt__',
#      '__module__',
#      '__name__',
#      '__ne__',
#      '__new__',
#      '__qualname__',
#      '__reduce__',
#      '__reduce_ex__',
#      '__repr__',
#      '__setattr__',
#      '__sizeof__',
#      '__str__',
#      '__subclasshook__']},
#    'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001C6A80E5488>>,
#    'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1c6a81222c8>,
#    'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1c6a81222c8>,
#    '_': ['__annotations__',
#     '__call__',
#     '__class__',
#     '__closure__',
#     '__code__',
#     '__defaults__',
#     '__delattr__',
#     '__dict__',
#     '__dir__',
#     '__doc__',
#     '__eq__',
#     '__format__',
#     '__ge__',
#     '__get__',
#     '__getattribute__',
#     '__globals__',
#     '__gt__',
#     '__hash__',
#     '__init__',
#     '__init_subclass__',
#     '__kwdefaults__',
#     '__le__',
#     '__lt__',
#     '__module__',
#     '__name__',
#     '__ne__',
#     '__new__',
#     '__qualname__',
#     '__reduce__',
#     '__reduce_ex__',
#     '__repr__',
#     '__setattr__',
#     '__sizeof__',
#     '__str__',
#     '__subclasshook__'],
#    '__': function,
#    '___': True,
#    '_i': 'inspect.getmembers(foo)',
#    '_ii': 'dir(foo)',
#    '_iii': 'dir(function)',
#    '_i1': "a = 1\nb = 2\n\ndef my_func(x):\n    'print the argument'\n    c = 3\n    d = 4\n    print(x)",
#    'a': 1,
#    'b': 2,
#    'my_func': <function __main__.my_func(x)>,
#    '_i2': "my_func('hello')",
#    '_i3': 'globals()',
#    '_3': {...},
#    '_i4': 'locals()',
#    '_4': {...},
#    '_i5': 'print(globals())',
#    '_i6': 'from pprint import pprint\n\npprint(globals())',
#    'pprint': <function pprint.pprint(object, stream=None, indent=1, width=80, depth=None, *, compact=False)>,
#    '_i7': 'locals() == globals()',
#    '_7': True,
#    '_i8': 'def foo():\n    x = 30 # x and y are local variables\n    y = 40\n\n    print("locals() = {0}".format(locals()))',
#    'foo': <function __main__.foo()>,
#    '_i9': 'foo()',
#    '_i10': 'def foo():\n    x = 30 # x and y are local variables\n    y = 40\n\n    print("locals() = {0}".format(locals()))\n    print(\'*\'*20)\n    print(locals())',
#    '_i11': 'foo()',
#    '_i12': 'def foo():\n    x = 30 # x and y are local variables\n    y = 40\n\n    print("locals() = {0}".format(locals()))\n    print(\'*\'*30)\n    print(locals())',
#    '_i13': 'foo()',
#    '_i14': 'def foo():\n    x = 30 # x and y are local variables\n    y = 40\n\n    print("locals() = {0}".format(locals()))\n    print(\'*\'*30)\n    print(\'locals:\')\n    print(locals())\n    print(\'*\'*30)\n    print(\'globals:\')\n    print(globals())',
#    '_i15': 'foo()',
#    '_i16': 'def foo():\n    x = 30 # x and y are local variables\n    y = 40\n\n    print("locals() = {0}".format(locals()))\n    print(\'*\'*30)\n    print(\'locals:\')\n    print(locals())\n    #print(\'*\'*30)\n    #print(\'globals:\')\n    #print(globals())',
#    '_i17': 'foo()',
#    '_i18': 'type(foo)',
#    '_18': function,
#    '_i19': 'functio',
#    '_i20': 'function',
#    '_i21': 'dir(function)',
#    '_i22': 'dir(foo)',
#    '_22': ['__annotations__',
#     '__call__',
#     '__class__',
#     '__closure__',
#     '__code__',
#     '__defaults__',
#     '__delattr__',
#     '__dict__',
#     '__dir__',
#     '__doc__',
#     '__eq__',
#     '__format__',
#     '__ge__',
#     '__get__',
#     '__getattribute__',
#     '__globals__',
#     '__gt__',
#     '__hash__',
#     '__init__',
#     '__init_subclass__',
#     '__kwdefaults__',
#     '__le__',
#     '__lt__',
#     '__module__',
#     '__name__',
#     '__ne__',
#     '__new__',
#     '__qualname__',
#     '__reduce__',
#     '__reduce_ex__',
#     '__repr__',
#     '__setattr__',
#     '__sizeof__',
#     '__str__',
#     '__subclasshook__'],
#    '_i23': 'inspect.getmembers(foo)',
#    '_i24': 'import inspect\ninspect.getmembers(foo)',
#    'inspect': <module 'inspect' from 'C:\\Users\\30694\\anaconda3\\lib\\inspect.py'>}),
#  ('__gt__',
#   <method-wrapper '__gt__' of function object at 0x000001C6A959B828>),
#  ('__hash__',
#   <method-wrapper '__hash__' of function object at 0x000001C6A959B828>),
#  ('__init__',
#   <method-wrapper '__init__' of function object at 0x000001C6A959B828>),
#  ('__init_subclass__', <function function.__init_subclass__>),
#  ('__kwdefaults__', None),
#  ('__le__',
#   <method-wrapper '__le__' of function object at 0x000001C6A959B828>),
#  ('__lt__',
#   <method-wrapper '__lt__' of function object at 0x000001C6A959B828>),
#  ('__module__', '__main__'),
#  ('__name__', 'foo'),
#  ('__ne__',
#   <method-wrapper '__ne__' of function object at 0x000001C6A959B828>),
#  ('__new__', <function function.__new__(*args, **kwargs)>),
#  ('__qualname__', 'foo'),
#  ('__reduce__', <function function.__reduce__()>),
#  ('__reduce_ex__', <function function.__reduce_ex__(protocol, /)>),
#  ('__repr__',
#   <method-wrapper '__repr__' of function object at 0x000001C6A959B828>),
#  ('__setattr__',
#   <method-wrapper '__setattr__' of function object at 0x000001C6A959B828>),
#  ('__sizeof__', <function function.__sizeof__()>),
#  ('__str__',
#   <method-wrapper '__str__' of function object at 0x000001C6A959B828>),
#  ('__subclasshook__', <function function.__subclasshook__>)]
