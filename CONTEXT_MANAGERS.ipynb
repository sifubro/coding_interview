# %%
#Guarantted to close the file even if exception occurs
try:
    with open(fname, 'r') as f:
        pass
except OSError:
    pass

# %% [markdown]
# https://www.youtube.com/watch?v=-aKFBoZpiqA&list=PL-osiE80TeTt2d9bfVyTiXJA-UTHn6WwU&index=49

# %% [markdown]
# - open/close files
# - open/close databases
# - acquire and release locks

# %% [markdown]
# # Using a class

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# with Open_file() --> runs the __enter__(self) method whitch open the file and returns it
#
# then this is set as the f variable (f = self.file from __enter__)
#
# Afterwards we execute the indeted block of with statement and finally after we exit the indented block we execute the __exit__ function

# %%
## Context managers
## __enter__
## __exit__

open()
file.close()

# %% [markdown]
# ## Using a function + decorator + generators

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# yielf f --> Is the same as returning the file from the __enter__ class method. It is going to yield the file and that is exactly what as f will be in the with statement.
#
# Then we run whatever is in the indeted block inside the with statement
#
# After we exit the indented block of with statement, then everything that follows the yield will execute i.e. f.close() the teardown

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
