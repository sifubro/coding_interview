# %% [markdown]
# - https://www.youtube.com/watch?v=x3v9zMX1s4s&list=PL-osiE80TeTt2d9bfVyTiXJA-UTHn6WwU&index=32

# %% [markdown]
# ## isinstance cheks not pythonic

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Asking for permission not pythonic!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### pythonic

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## isinstance()
# ## hasattrr()
# ## callable()
# ## setattr(object, name, value)

# %%
class Person:
    name = 'John'
    
p = Person()
setattr(p, 'name', 'Theo')
p.name
# Out:
# 'Theo'

# %%
setattr(p, 'age', 33)
p.age
# Out:
# 33

# %%
hasattr(p, 'age')
# Out:
# True

# %%
hasattr(p, 'ulti')
# Out:
# False

# %%
callable(p)
# Out:
# False

# %%
 callable(Person)
# Out:
# True
