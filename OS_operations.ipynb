# %% [markdown]
# Lecture 22
# - https://www.youtube.com/watch?v=tJxcKyFMTGo&list=PL-osiE80TeTt2d9bfVyTiXJA-UTHn6WwU&index=23

# %% [markdown]
# ## Make directory and subdirectories

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\30694\\Desktop\\ML-STATS\\ML-AI\\Theo_ML'

# %%
## Change directory

# %%
os.chdir('C:\\Users\\30694\\Desktop\\ML-STATS\\ML-AI\\')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\30694\\Desktop\\ML-STATS\\ML-AI'

# %%
import os

# To make directories 
def mkdir(paths):
    for path in paths:
        if not os.path.isdir(path): #Return True if path is an existing directory.
            os.makedirs(path)
            
#os.rmdir(directory)

# For Pytorch data loader
def create_link(dataset_dir):
    dirs = {}
    dirs['trainA'] = os.path.join(dataset_dir, 'ltrainA')
    dirs['trainB'] = os.path.join(dataset_dir, 'ltrainB')
    dirs['testA'] = os.path.join(dataset_dir, 'ltestA')
    dirs['testB'] = os.path.join(dataset_dir, 'ltestB')
    mkdir(dirs.values())

# %% [markdown]
# ## Better method that works with nested dirs!

# %%
os.makedirs('C:\Users\30694\Desktop\make_dir1\make_dir2\make_dir3')
#os.removedirs

# %%
dataset_dir = r'C:\Users\30694\Desktop\make_dir'

create_link(dataset_dir)

# %% [markdown]
# - https://stackoverflow.com/questions/37863476/why-would-one-use-both-os-path-abspath-and-os-path-realpath

# %%
os.stat('demo.txt')

# %% [markdown]
# ## size of file

# %%
os.stat('demo.txt').st_size

# %% [markdown]
# ## Time created

# %%
os.stat('demo.txt').st_mtime

# %% [markdown]
# ## os.walk

# %%
9:30

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # os.path.join   files

# %%
os.path.basename(path)

os.path.dirname(path)

os.path.split(path)
