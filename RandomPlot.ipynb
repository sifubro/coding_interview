# %%
import numpy as np

# %%
a= np.linspace(-5,5,50)

# %%
a
# Out:
# array([-5.        , -4.47368421, -3.94736842, -3.42105263, -2.89473684,
#        -2.36842105, -1.84210526, -1.31578947, -0.78947368, -0.26315789,
#         0.26315789,  0.78947368,  1.31578947,  1.84210526,  2.36842105,
#         2.89473684,  3.42105263,  3.94736842,  4.47368421,  5.        ])

# %%
a.reshape(-1,1)
# Out:
# array([[-5.        ],
#        [-4.79591837],
#        [-4.59183673],
#        [-4.3877551 ],
#        [-4.18367347],
#        [-3.97959184],
#        [-3.7755102 ],
#        [-3.57142857],
#        [-3.36734694],
#        [-3.16326531],
#        [-2.95918367],
#        [-2.75510204],
#        [-2.55102041],
#        [-2.34693878],
#        [-2.14285714],
#        [-1.93877551],
#        [-1.73469388],
#        [-1.53061224],
#        [-1.32653061],
#        [-1.12244898],
#        [-0.91836735],
#        [-0.71428571],
#        [-0.51020408],
#        [-0.30612245],
#        [-0.10204082],
#        [ 0.10204082],
#        [ 0.30612245],
#        [ 0.51020408],
#        [ 0.71428571],
#        [ 0.91836735],
#        [ 1.12244898],
#        [ 1.32653061],
#        [ 1.53061224],
#        [ 1.73469388],
#        [ 1.93877551],
#        [ 2.14285714],
#        [ 2.34693878],
#        [ 2.55102041],
#        [ 2.75510204],
#        [ 2.95918367],
#        [ 3.16326531],
# ...

# %%
import matplotlib.pyplot as plt

# %%
f= np.random.normal(size=(20,10))

# %%
f
# Out:
# array([[-0.66752612,  1.34141961,  0.25598113,  0.29010644, -0.26341685,
#          0.20397738,  1.02549467,  0.62601311, -1.41999832, -0.29434391],
#        [ 0.61827162, -0.13732422, -2.46671095, -0.79387713,  1.18718778,
#          2.3292685 ,  0.56421706, -0.4914193 , -1.69920056,  0.18606173],
#        [-0.25601885, -0.4293281 ,  1.08257796,  0.60867108, -0.8172861 ,
#         -0.73681546,  1.30989808,  0.85043518, -1.35536747, -1.83333271],
#        [ 0.78842033, -0.7379103 , -1.1607926 ,  1.10718315, -1.38569828,
#          1.18394806,  1.62858169, -0.51972266,  0.70668293, -0.41778096],
#        [-0.91809391,  0.30259133, -0.00599602,  0.37417091,  0.26914489,
#          0.12118421,  0.00612945,  1.09342671,  0.53705784,  1.08304006],
#        [ 3.20913576, -0.28966373, -1.35402656, -2.05626665, -0.22423386,
#         -0.99577221, -0.73000698, -0.49917699,  1.25773849, -0.70316816],
#        [-0.09417135,  2.7815921 ,  0.86210058, -1.73418017, -0.1091026 ,
# ...

# %%
plt.plot(a,f)

# %%
f= np.random.normal(size=(50,1))

# %%
plt.plot(a,f)
