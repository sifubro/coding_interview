# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.3.1-cp37-cp37m-win_amd64.whl (342.5 MB)
# Collecting tensorboard<3,>=2.3.0
#   Downloading tensorboard-2.4.0-py3-none-any.whl (10.6 MB)
# Processing c:\users\30694\appdata\local\pip\cache\wheels\7c\06\54\bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6\termcolor-1.1.0-cp37-none-any.whl
# Collecting gast==0.3.3
#   Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\30694\anaconda3\lib\site-packages (from tensorflow) (1.11.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\30694\anaconda3\lib\site-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in c:\users\30694\anaconda3\lib\site-packages (from tensorflow) (1.18.1)
# Collecting grpcio>=1.8.6
#   Downloading grpcio-1.33.2-cp37-cp37m-win_amd64.whl (2.5 MB)
# Collecting tensorflow-estimator<2.4.0,>=2.3.0
#   Downloading tensorflow_estimator-2.3.0-py2.py3-none-any.whl (459 kB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.13.0-cp37-cp37m-win_amd64.whl (1.0 MB)
# Requirement already satisfied: wheel>=0.26 in c:\users\30694\anaconda3\lib\site-packages (from tensorflow) (0.34.2)
# Collecting absl-py>=0.7.0
#   Downloading absl_py-0.11.0-py3-none-any.whl (127 kB)
# Collecting keras-preprocessing<1.2,>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in c:\users\30694\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Collecting google-pasta>=0.1.8
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting astunparse==1.6.3
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\30694\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (45.2.0.post20200210)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.23.0-py2.py3-none-any.whl (114 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.7.0-py3-none-any.whl (779 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\30694\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (2.22.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\30694\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.0.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.2-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.3-py3-none-any.whl (96 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.5"
#   Downloading rsa-4.6-py3-none-any.whl (47 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.1.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\30694\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\30694\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\30694\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\30694\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2019.11.28)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\30694\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (1.5.0)
# Collecting pyasn1>=0.1.3
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\30694\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (2.2.0)
# Installing collected packages: protobuf, grpcio, absl-py, pyasn1, rsa, pyasn1-modules, cachetools, google-auth, tensorboard-plugin-wit, oauthlib, requests-oauthlib, google-auth-oauthlib, markdown, tensorboard, termcolor, gast, tensorflow-estimator, opt-einsum, keras-preprocessing, google-pasta, astunparse, tensorflow
# Successfully installed absl-py-0.11.0 astunparse-1.6.3 cachetools-4.1.1 gast-0.3.3 google-auth-1.23.0 google-auth-oauthlib-0.4.2 google-pasta-0.2.0 grpcio-1.33.2 keras-preprocessing-1.1.2 markdown-3.3.3 oauthlib-3.1.0 opt-einsum-3.3.0 protobuf-3.13.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.6 tensorboard-2.4.0 tensorboard-plugin-wit-1.7.0 tensorflow-2.3.1 tensorflow-estimator-2.3.0 termcolor-1.1.0

# %% [markdown]
# ### https://www.tensorflow.org/tutorials/text/image_captioning

# %%
import tensorflow as tf

# You'll generate plots of attention in order to see which parts of an image
# our model focuses on during captioning
import matplotlib.pyplot as plt

# Scikit-learn includes many helpful utilities
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

import collections
import random
import re
import numpy as np
import os
import time
import json
from glob import glob
from PIL import Image
import pickle

# %%
image_model = tf.keras.applications.InceptionV3(include_top=False,
                                                weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 45s 1us/step

# %%
image_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, None, None, 3 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, None, None, 3 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, None, None, 3 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 6 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 6 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, None, None, 6 0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 8 5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 8 240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 8 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 1 138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 1 576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 1 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 1 0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 6 12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 6 192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 4 9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 9 55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 4 144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 9 288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 4 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 9 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, None, None, 1 0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 6 12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 6 76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 9 82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 3 6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 6 192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 6 192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 9 288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 3 96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 6 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 9 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 3 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, None, None, 2 0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 6 192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 6 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 4 12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 9 55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 4 144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 9 288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 4 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 9 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, None, None, 2 0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 6 76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 9 82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 6 16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 6 192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 6 192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 9 288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 6 192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 6 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 6 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 9 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 6 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, None, None, 2 0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, None, None, 6 192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 6 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 4 13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 9 55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, None, None, 4 144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, None, None, 9 288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 4 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 9 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, None, None, 2 0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 6 76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 9 82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 6 18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, None, None, 6 192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, None, None, 6 192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, None, None, 9 288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, None, None, 6 192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 6 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 6 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 9 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 6 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, None, None, 2 0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 6 18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, None, None, 6 192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 6 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 9 55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, None, None, 9 288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 9 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 3 995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 9 82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, None, None, 3 1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, None, None, 9 288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 3 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 9 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 2 0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, None, None, 7 0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, None, None, 1 384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, None, None, 1 114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, None, None, 1 384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 1 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, None, None, 1 114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, None, None, 1 384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, None, None, 1 384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 1 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 1 114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, None, None, 1 114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, None, None, 1 384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, None, None, 1 384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 1 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, None, None, 7 0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, None, None, 1 147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 1 172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, None, None, 1 172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, None, None, 1 147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, None, None, 1 576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, None, None, 1 576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, None, None, 1 576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, None, None, 1 576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 1 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 1 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 1 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 1 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, None, None, 7 0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, None, None, 1 480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, None, None, 1 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, None, None, 1 179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, None, None, 1 480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, None, None, 1 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, None, None, 1 179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, None, None, 1 480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, None, None, 1 480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, None, None, 1 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, None, None, 1 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, None, None, 1 179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, None, None, 1 179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, None, None, 1 480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, None, None, 1 480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, None, None, 1 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, None, None, 1 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, None, None, 7 0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, None, None, 1 147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, None, None, 1 215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, None, None, 1 215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, None, None, 1 147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, None, None, 1 576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, None, None, 1 576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, None, None, 1 576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, None, None, 1 576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, None, None, 1 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, None, None, 1 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, None, None, 1 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, None, None, 7 0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, None, None, 1 480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, None, None, 1 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, None, None, 1 179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, None, None, 1 480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, None, None, 1 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, None, None, 1 179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, None, None, 1 480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, None, None, 1 480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, None, None, 1 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, None, None, 1 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, None, None, 1 179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, None, None, 1 179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, None, None, 1 480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, None, None, 1 480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, None, None, 1 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 1 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, None, None, 7 0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, None, None, 1 147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, None, None, 1 215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, None, None, 1 215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, None, None, 1 147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, None, None, 1 576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, None, None, 1 576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, None, None, 1 576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, None, None, 1 576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 1 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, None, None, 1 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, None, None, 1 0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, None, None, 1 0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, None, None, 7 0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, None, None, 1 576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, None, None, 1 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, None, None, 1 258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, None, None, 1 576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, None, None, 1 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, None, None, 1 258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, None, None, 1 576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, None, None, 1 576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, None, None, 1 0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, None, None, 1 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, None, None, 1 258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, None, None, 1 258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, None, None, 1 576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, None, None, 1 576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, None, None, 1 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, None, None, 1 0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, None, None, 7 0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, None, None, 1 258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, None, None, 1 258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, None, None, 1 147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, None, None, 1 576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, None, None, 1 576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, None, None, 1 576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, None, None, 1 576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, None, None, 1 0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, None, None, 1 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, None, None, 1 0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, None, None, 1 0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, None, None, 7 0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, None, None, 1 576         conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, None, None, 1 0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, None, None, 1 0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, None, None, 3 552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, None, None, 1 331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, None, None, 3 960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, None, None, 1 576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, None, None, 3 0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, None, None, 1 0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 7 0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, None, None, 1 0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, None, None, 4 573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, None, None, 4 1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, None, None, 4 0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, None, None, 3 491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, None, None, 3 1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, None, None, 3 1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, None, None, 3 1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, None, None, 3 0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, None, None, 3 0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, None, None, 3 442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, None, None, 3 442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, None, None, 3 442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, None, None, 3 442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, None, None, 1 0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, None, None, 3 409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, None, None, 3 1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, None, None, 3 1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, None, None, 3 1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, None, None, 3 1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, None, None, 1 245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, None, None, 3 960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, None, None, 3 0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, None, None, 3 0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, None, None, 3 0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, None, None, 3 0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, None, None, 1 576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, None, None, 3 0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, None, None, 7 0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, None, None, 7 0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, None, None, 1 0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, None, None, 2 0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, None, None, 4 917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, None, None, 4 1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, None, None, 4 0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, None, None, 3 786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, None, None, 3 1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, None, None, 3 1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, None, None, 3 1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, None, None, 3 0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, None, None, 3 0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, None, None, 3 442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, None, None, 3 442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, None, None, 3 442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, None, None, 3 442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, None, None, 2 0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, None, None, 3 655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, None, None, 3 1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, None, None, 3 1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, None, None, 3 1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, None, None, 3 1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, None, None, 1 393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, None, None, 3 960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, None, None, 3 0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, None, None, 3 0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, None, None, 3 0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, None, None, 3 0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, None, None, 1 576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, None, None, 3 0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, None, None, 7 0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 7 0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, None, None, 1 0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, None, None, 2 0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
new_input = image_model.input
hidden_layer = image_model.layers[-1].output

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)

# %%
image_features_extract_model

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (299, 299))
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

# %%
image_folder = 'D://Panoptic_2017/train2017/'

# %%
with open('D://Panoptic_2017/captions_train2017.json', 'r') as f:
    annotations = json.load(f)

# %%
annotations.keys()
# Out:
# dict_keys(['info', 'licenses', 'images', 'annotations'])

# %%
annotations['annotations']
# Out:
# [{'image_id': 203564,
#   'id': 37,
#   'caption': 'A bicycle replica with a clock as the front wheel.'},
#  {'image_id': 322141,
#   'id': 49,
#   'caption': 'A room with blue walls and a white sink and door.'},
#  {'image_id': 16977,
#   'id': 89,
#   'caption': 'A car that seems to be parked illegally behind a legally parked car'},
#  {'image_id': 106140,
#   'id': 98,
#   'caption': 'A large passenger airplane flying through the air.'},
#  {'image_id': 106140,
#   'id': 101,
#   'caption': 'There is a GOL plane taking off in a partly cloudy sky.'},
#  {'image_id': 322141,
#   'id': 109,
#   'caption': 'Blue and white color scheme in a small bathroom.'},
#  {'image_id': 322141,
#   'id': 121,
#   'caption': 'This is a blue and white bathroom with a wall sink and a lifesaver on the wall.'},
#  {'image_id': 322141,
#   'id': 163,
#   'caption': 'A blue boat themed bathroom with a life preserver on the wall'},
#  {'image_id': 203564, 'id': 181, 'caption': 'The bike has a clock as a tire.'},
#  {'image_id': 16977,
#   'id': 185,
#   'caption': 'two cars parked on the sidewalk on the street'},
#  {'image_id': 106140,
#   'id': 221,
#   'caption': 'An airplane that is, either, landing or just taking off.'},
#  {'image_id': 322141,
#   'id': 250,
#   'caption': 'A bathroom with walls that are painted baby blue.'},
#  {'image_id': 571635,
#   'id': 342,
#   'caption': 'A bathroom with a toilet, sink, and shower.'},
#  {'image_id': 301837,
#   'id': 391,
#   'caption': 'A long empty, minimal modern skylit home kitchen.'},
#  {'image_id': 315702,
#   'id': 437,
#   'caption': 'A bathroom sink with toiletries on the counter.'},
#  {'image_id': 315702,
#   'id': 452,
#   'caption': 'A bathroom sink and various personal hygiene items.'},
#  {'image_id': 189634,
#   'id': 455,
#   'caption': 'This is an open box containing four cucumbers.'},
#  {'image_id': 472598,
#   'id': 456,
#   'caption': 'An old-fashioned green station wagon is parked on a shady driveway.'},
#  {'image_id': 162113,
#   'id': 464,
#   'caption': 'A gas stove next to a stainless steel kitchen sink and countertop.'},
#  {'image_id': 203564,
#   'id': 478,
#   'caption': 'A black metal bicycle with a clock inside the front wheel.'},
#  {'image_id': 126657,
#   'id': 565,
#   'caption': 'Several motorcycles riding down the road in formation.'},
#  {'image_id': 285421,
#   'id': 589,
#   'caption': 'A black cat is inside a white toilet.'},
#  {'image_id': 16977,
#   'id': 626,
#   'caption': 'City street with parked cars and a bench.'},
#  {'image_id': 71988,
#   'id': 699,
#   'caption': 'A man in a wheelchair and another sitting on a bench that is overlooking the water.'},
#  {'image_id': 193622,
#   'id': 701,
#   'caption': 'A man sits with a traditionally decorated cow'},
#  {'image_id': 459912,
#   'id': 748,
#   'caption': 'Rows of motor bikes and helmets in a city'},
#  {'image_id': 548498,
#   'id': 754,
#   'caption': 'A cute kitten is sitting in a dish on a table.'},
#  {'image_id': 315702,
#   'id': 791,
#   'caption': 'A messy bathroom countertop perched atop black cabinetry.'},
#  {'image_id': 52087,
#   'id': 827,
#   'caption': 'A man getting a drink from a water fountain that is a toilet.'},
#  {'image_id': 189634,
#   'id': 833,
#   'caption': 'An open food container box with four unknown food items.'},
#  {'image_id': 472598,
#   'id': 834,
#   'caption': 'An old teal colored car parked on the street.'},
#  {'image_id': 119964,
#   'id': 891,
#   'caption': 'A person holding a skateboard overlooks a dead field of crops.'},
#  {'image_id': 126657,
#   'id': 931,
#   'caption': 'A group of motorcycle riders driving past buildings.'},
#  {'image_id': 230610,
#   'id': 935,
#   'caption': 'A bathroom with a sink and shower curtain with a map print.'},
#  {'image_id': 226419,
#   'id': 939,
#   'caption': 'A random plane in the sky flying alone'},
#  {'image_id': 226419,
#   'id': 945,
#   'caption': 'An airplane flying high in the blue sky. '},
#  {'image_id': 218026,
#   'id': 961,
#   'caption': 'A brown and black horse in the middle of the city eating grass.'},
#  {'image_id': 352538,
#   'id': 974,
#   'caption': 'A brown purse is sitting on a green bench.'},
#  {'image_id': 202913,
#   'id': 1034,
#   'caption': 'Half of a white cake with coconuts on top.'},
#  {'image_id': 202658,
#   'id': 1037,
#   'caption': 'An old toilet with a hello kitty cover top. '},
#  {'image_id': 79472,
#   'id': 1104,
#   'caption': 'Office space with office equipment on desk top.'},
#  {'image_id': 346071,
#   'id': 1113,
#   'caption': "Two husky's hanging out of the car windows."},
#  {'image_id': 6672,
#   'id': 1132,
#   'caption': 'The back door with a window in the kitchen.'},
#  {'image_id': 419074,
#   'id': 1137,
#   'caption': 'Jet liner flying off into the distance on an overcast day'},
#  {'image_id': 382406,
#   'id': 1221,
#   'caption': 'A woman is walking a dog in the city.'},
#  {'image_id': 16977,
#   'id': 1229,
#   'caption': 'Cars try to maneuver into parking spaces along a densely packed city street. '},
#  {'image_id': 346071,
#   'id': 1248,
#   'caption': 'Dogs stick their heads out of car windows'},
#  {'image_id': 119964,
#   'id': 1302,
#   'caption': 'A person sits on a patch of grass observing the scenery.'},
#  {'image_id': 175948,
#   'id': 1327,
#   'caption': 'A tiny bathroom with only a toilet and a shelf.'},
#  {'image_id': 573223,
#   'id': 1373,
#   'caption': 'A little girl in a public bathroom for kids.'},
#  {'image_id': 52087,
#   'id': 1400,
#   'caption': 'A boy drinking water from a toilet water fountain.'},
#  {'image_id': 402514,
#   'id': 1436,
#   'caption': 'A picture of a man playing a violin in a kitchen.'},
#  {'image_id': 230610,
#   'id': 1484,
#   'caption': 'A small and crowded bathroom with little furnishing '},
#  {'image_id': 407286,
#   'id': 1494,
#   'caption': "A trio of dogs sitting in their owner's lap in a red convertible."},
#  {'image_id': 82673,
#   'id': 1562,
#   'caption': 'A small car is parked in front of a scooter'},
#  {'image_id': 382406,
#   'id': 1620,
#   'caption': 'A woman and her dog walking down a sidewalk next to a fence with some flowers. '},
#  {'image_id': 141172,
#   'id': 1637,
#   'caption': 'A door with a sticker of a cat door on it'},
#  {'image_id': 104326,
#   'id': 1693,
#   'caption': 'A pinewood and green modern themed kitchen area.'},
#  {'image_id': 402514,
#   'id': 1706,
#   'caption': 'A man is playing violin in his kitchen'},
#  {'image_id': 581177,
#   'id': 1766,
#   'caption': 'A kitchen is shown with wooden cabinets and a wooden celling.'},
#  {'image_id': 267802,
#   'id': 1774,
#   'caption': 'A group of people riding mopeds in a busy street. '},
#  {'image_id': 208408,
#   'id': 1828,
#   'caption': 'A person walking in the rain on the sidewalk. '},
#  {'image_id': 581177,
#   'id': 1865,
#   'caption': 'A recently remodeled kitchen with marble and wooden furnishings.'},
#  {'image_id': 560591,
#   'id': 1886,
#   'caption': 'a modern flush toilet in a bathroom with tile. '},
#  {'image_id': 189634,
#   'id': 1907,
#   'caption': 'A small box filled with four green vegetables. '},
#  {'image_id': 472598,
#   'id': 1908,
#   'caption': 'A classic car sitting beside the road with a surfboard on top. '},
#  {'image_id': 507362,
#   'id': 1933,
#   'caption': 'Fog is in the air at an intersection with several traffic lights.'},
#  {'image_id': 407286,
#   'id': 2028,
#   'caption': "Three little dogs looking out a car window while sitting on a woman's lap. "},
#  {'image_id': 52087,
#   'id': 2045,
#   'caption': 'A young man drinking from a water fountain in the shape of a toilet.'},
#  {'image_id': 57429,
#   'id': 2049,
#   'caption': 'An airplane with its landing wheels out landing. '},
#  {'image_id': 153184,
#   'id': 2076,
#   'caption': 'Little birds sitting on the shoulder of a giraffe. '},
#  {'image_id': 382406,
#   'id': 2091,
#   'caption': 'A woman walking her dog on the sidewalk.'},
#  {'image_id': 571970, 'id': 2099, 'caption': 'a man with a bike at a marina'},
#  {'image_id': 153184,
#   'id': 2121,
#   'caption': "The top of a giraffe's head has birds on it."},
#  {'image_id': 57429,
#   'id': 2139,
#   'caption': 'A plane that is taking off at an airport'},
#  {'image_id': 133680,
#   'id': 2152,
#   'caption': 'A man is sitting on a bench next to a bike.'},
#  {'image_id': 139011,
#   'id': 2154,
#   'caption': 'People are waiting for the bus near a bus stop.'},
#  {'image_id': 6672,
#   'id': 2155,
#   'caption': 'The kitchen has a white door with a window.'},
#  {'image_id': 104326,
#   'id': 2167,
#   'caption': 'A kitchen and dining room area with a large window.'},
#  {'image_id': 505386,
#   'id': 2192,
#   'caption': 'four urinals in a public restroom with a window'},
#  {'image_id': 106140,
#   'id': 2219,
#   'caption': 'An red and white airplane is in the cloudy sky.'},
#  {'image_id': 285421,
#   'id': 2242,
#   'caption': 'A black cat drinking water from a toilet'},
#  {'image_id': 581177,
#   'id': 2258,
#   'caption': 'Well kept kitchen with marble counter tops and stainless steel fridge'},
#  {'image_id': 79472,
#   'id': 2376,
#   'caption': 'A hope office setup of computers and printers.'},
#  {'image_id': 208408,
#   'id': 2383,
#   'caption': 'A person walking through the rain with an umbrella.'},
#  {'image_id': 107990,
#   'id': 2405,
#   'caption': 'A small child climbs atop a large motorcycle'},
#  {'image_id': 527510,
#   'id': 2450,
#   'caption': 'A large U.S Air Force plain sits on an asphalt ramp.'},
#  {'image_id': 5247,
#   'id': 2473,
#   'caption': 'A black and white photo of an older man skiing.'},
#  {'image_id': 505386,
#   'id': 2576,
#   'caption': 'A bathroom with four urinals on the wall.'},
#  {'image_id': 301837,
#   'id': 2599,
#   'caption': 'A picture of a modern looking kitchen area\n'},
#  {'image_id': 79472,
#   'id': 2607,
#   'caption': 'a home office with laptop, printer, scanner, and extra monitor'},
#  {'image_id': 5247,
#   'id': 2620,
#   'caption': 'Two people on the snow for cross country skiing.'},
#  {'image_id': 107960,
#   'id': 2655,
#   'caption': 'Riding a motorcycle down a street that has no one else on it.'},
#  {'image_id': 162113,
#   'id': 2666,
#   'caption': 'A kitchen stove, sink, and counter with stuff on it.'},
#  {'image_id': 133680,
#   'id': 2686,
#   'caption': 'A man is sitting on a bench next to a bicycle.'},
#  {'image_id': 139011,
#   'id': 2688,
#   'caption': 'A crowd of people are waiting to get on a red bus.'},
#  {'image_id': 285421,
#   'id': 2761,
#   'caption': 'A cat drinking water from a toilet in a bathroom.'},
#  {'image_id': 507362,
#   'id': 2830,
#   'caption': 'An intersection during a cold and foggy night.'},
#  {'image_id': 208408,
#   'id': 2884,
#   'caption': 'A person walking in the rain while holding an umbrella.'},
#  {'image_id': 407286,
#   'id': 2919,
#   'caption': 'A woman driver has three dogs in the seat with her.'},
#  {'image_id': 57429,
#   'id': 2946,
#   'caption': 'A man takes a picture of an airplane taking off.'},
#  {'image_id': 410627,
#   'id': 2961,
#   'caption': 'The young man is stirring his pot of food with a wooden spoon.'},
#  {'image_id': 232223,
#   'id': 3001,
#   'caption': 'A fighter jet is flying at a fast speed.'},
#  {'image_id': 22793,
#   'id': 3043,
#   'caption': 'A public bathroom with a bunch of urinals.'},
#  {'image_id': 436456,
#   'id': 3106,
#   'caption': 'The airplane is on the runway with two young men standing by.'},
#  {'image_id': 581177,
#   'id': 3125,
#   'caption': 'A beautiful new kitchen with natural wood cabinets.'},
#  {'image_id': 368402,
#   'id': 3192,
#   'caption': 'The woman in the kitchen is holding a huge pan.'},
#  {'image_id': 107990,
#   'id': 3200,
#   'caption': 'A young boy riding a motorcycle next to a silver car.'},
#  {'image_id': 135161,
#   'id': 3205,
#   'caption': 'A toilet sits next to a window and in front of a shower.'},
#  {'image_id': 382406,
#   'id': 3237,
#   'caption': 'A woman walks her dog along a city street.'},
#  {'image_id': 107990,
#   'id': 3302,
#   'caption': 'A little baby is sitting on a huge motorcycle.'},
#  {'image_id': 505386,
#   'id': 3362,
#   'caption': 'An old bathroom with a row of urinals.'},
#  {'image_id': 581177,
#   'id': 3365,
#   'caption': 'A neat, wood filled kitchen is photographed as if for a real estate ad.'},
#  {'image_id': 407286,
#   'id': 3417,
#   'caption': 'A woman and her three dogs in a car.'},
#  {'image_id': 230610,
#   'id': 3446,
#   'caption': 'A small bathroom with a shower curtain with the NYC Subway map on it. '},
#  {'image_id': 230610,
#   'id': 3455,
#   'caption': 'A bathroom with a map as a shower curtain. '},
#  {'image_id': 16977,
#   'id': 3506,
#   'caption': 'A couple of cars parked in a busy street sidewalk.'},
#  {'image_id': 106140,
#   'id': 3560,
#   'caption': 'A passenger plane taking off into the sky. '},
#  {'image_id': 6672,
#   'id': 3577,
#   'caption': 'A kitchen door next to a kitchen sing and counter top.'},
#  {'image_id': 178761,
#   'id': 3586,
#   'caption': 'A dog and a goat with their noses touching at fence.'},
#  {'image_id': 301837,
#   'id': 3694,
#   'caption': 'A narrow kitchen ending with a chrome refrigerator.'},
#  {'image_id': 107990,
#   'id': 3710,
#   'caption': 'A little boy sitting alone on a motorcycle.'},
#  {'image_id': 573223,
#   'id': 3728,
#   'caption': 'A girl standing next to a toilet in a bathroom.'},
#  {'image_id': 491000,
#   'id': 3753,
#   'caption': 'Pedestrians walking down a sidewalk next to a small street.'},
#  {'image_id': 368402,
#   'id': 3759,
#   'caption': 'A chef carrying a large pan inside of a kitchen.'},
#  {'image_id': 419074,
#   'id': 3762,
#   'caption': 'An airplane flying away in a cloudy sky.'},
#  {'image_id': 571635,
#   'id': 3765,
#   'caption': 'A full bathroom with a wicker laundry basket.'},
#  {'image_id': 71988,
#   'id': 3840,
#   'caption': 'Two people sitting on dock looking at the ocean.'},
#  {'image_id': 538092,
#   'id': 3903,
#   'caption': 'A man standing in a kitchen while closing a cupboard door.'},
#  {'image_id': 548498,
#   'id': 4027,
#   'caption': 'A small white cat on a large bowl.'},
#  {'image_id': 267802,
#   'id': 4036,
#   'caption': 'People riding bikes and cars down the street. '},
#  {'image_id': 226419,
#   'id': 4047,
#   'caption': 'A silver color jet flying through the clear sky.'},
#  {'image_id': 505386,
#   'id': 4052,
#   'caption': 'A row of urinals in with an open window above them.'},
#  {'image_id': 202913,
#   'id': 4100,
#   'caption': 'The coconut cake on a red plate is half gone.'},
#  {'image_id': 560591,
#   'id': 4118,
#   'caption': 'A toilet and trashcan in a white bathroom.'},
#  {'image_id': 571970,
#   'id': 4142,
#   'caption': 'A man stands next to his bike at the marina.'},
#  {'image_id': 71988,
#   'id': 4173,
#   'caption': 'Two older people sitting down in front of a beach.'},
#  {'image_id': 571970,
#   'id': 4190,
#   'caption': 'an old man standing next to a bike and a chain fence.'},
#  {'image_id': 230610,
#   'id': 4193,
#   'caption': 'A bathroom with pedestal sink and mirror over it.'},
#  {'image_id': 205577,
#   'id': 4205,
#   'caption': 'A photograph of a kitchen inside a house.'},
#  {'image_id': 508672,
#   'id': 4220,
#   'caption': 'a bike leaning on a metal fence next to some flowing water. '},
#  {'image_id': 52087,
#   'id': 4319,
#   'caption': 'A young person has his face close to the toilet bowl.'},
#  {'image_id': 419074,
#   'id': 4329,
#   'caption': 'A plane that is flying in a clear blue sky.'},
#  {'image_id': 119964,
#   'id': 4347,
#   'caption': 'A person holding a skate board sitting in an empty open field.'},
#  {'image_id': 352538,
#   'id': 4355,
#   'caption': 'a brown purse abandoned on a green bench.'},
#  {'image_id': 507362,
#   'id': 4372,
#   'caption': 'Empty fog covered streets in the night amongst traffic lights.'},
#  {'image_id': 334015,
#   'id': 4386,
#   'caption': 'a small toilet stall with a toilet brush and 3 rolls of toilet paper '},
#  {'image_id': 202913,
#   'id': 4397,
#   'caption': 'A half eaten dessert cake sitting on a cake plate.'},
#  {'image_id': 27842,
#   'id': 4451,
#   'caption': 'A dual sink vanity with mirrors above the sinks.'},
#  {'image_id': 52087,
#   'id': 4571,
#   'caption': 'A man taking a drink from a water fountain.'},
#  {'image_id': 5247,
#   'id': 4594,
#   'caption': 'The old man cross country skis through the forest.'},
#  {'image_id': 527510,
#   'id': 4604,
#   'caption': 'A large propeller airplane sitting on a tarmac.'},
#  {'image_id': 459912,
#   'id': 4633,
#   'caption': 'A lot of motorbikes line up down a busy street.'},
#  {'image_id': 153184,
#   'id': 4653,
#   'caption': 'Three birds sit on the back of a giraffe. '},
#  {'image_id': 358606,
#   'id': 4710,
#   'caption': 'A fireplace with a fire built in it.'},
#  {'image_id': 153184,
#   'id': 4731,
#   'caption': 'A giraffe with 3 birds on his fur.'},
#  {'image_id': 71988,
#   'id': 4740,
#   'caption': 'An old couple at the beach during the day.'},
#  {'image_id': 567730,
#   'id': 4774,
#   'caption': 'The sign of a restaurant in the outside of the store.'},
#  {'image_id': 193622,
#   'id': 4781,
#   'caption': 'A decorative man sits on the ground with a cow.'},
#  {'image_id': 567730,
#   'id': 4840,
#   'caption': 'A sign on a building advertising an Italian restaurant.'},
#  {'image_id': 202658,
#   'id': 4844,
#   'caption': 'A toilet with a Hello Kitty symbol on it.'},
#  {'image_id': 22793,
#   'id': 4852,
#   'caption': 'A picture of a woman hangs on the wall above the urinals.'},
#  {'image_id': 133680,
#   'id': 4855,
#   'caption': 'A man sits on a street bench by a bike. '},
#  {'image_id': 139011,
#   'id': 4857,
#   'caption': 'A crowd of people get ready to board a bus in the city.'},
#  {'image_id': 571970,
#   'id': 4949,
#   'caption': 'A man holding some break standing by a bicycle.'},
#  {'image_id': 175948,
#   'id': 4957,
#   'caption': 'Small bathroom with a toilet and a sink.'},
#  {'image_id': 505386,
#   'id': 4985,
#   'caption': 'A row of urinals stand beneath a open window.'},
#  {'image_id': 560591,
#   'id': 5006,
#   'caption': 'A white toilet sits on a tile floor.'},
#  {'image_id': 61259,
#   'id': 5008,
#   'caption': 'an airport with one plane flying away and the other sitting on the runway'},
#  {'image_id': 554037,
#   'id': 5010,
#   'caption': 'a counter with vegetables, knife and cutting board on it. '},
#  {'image_id': 5394,
#   'id': 5018,
#   'caption': 'A boat that looks like a car moves through the water. '},
#  {'image_id': 5394,
#   'id': 5024,
#   'caption': 'A car modified to drive in the water on a lake.'},
#  {'image_id': 455384,
#   'id': 5173,
#   'caption': 'A delivery truck with an advertisement for Entourage.'},
#  {'image_id': 249352,
#   'id': 5174,
#   'caption': 'A black and white toilet with a plunger.'},
#  {'image_id': 301837,
#   'id': 5209,
#   'caption': 'A narrow kitchen is decorated in shades of white, gray, and black.'},
#  {'image_id': 5247,
#   'id': 5227,
#   'caption': 'A younger man and an older man skiing in the forest.'},
#  {'image_id': 348306,
#   'id': 5283,
#   'caption': 'A bike leaning against a sign in Scotland.'},
#  {'image_id': 348306,
#   'id': 5292,
#   'caption': 'A bike in front of a scenic welcome sign. '},
#  {'image_id': 104326,
#   'id': 5338,
#   'caption': 'A green kitchen with wooden counters and bright lights. '},
#  {'image_id': 162113,
#   'id': 5369,
#   'caption': 'A kitchen with a stove, sink, and drying area. '},
#  {'image_id': 548498,
#   'id': 5377,
#   'caption': 'A small kitten is sitting in a bowl. '},
#  {'image_id': 189634,
#   'id': 5384,
#   'caption': 'An opened box of four chocolate bananas. '},
#  {'image_id': 472598,
#   'id': 5385,
#   'caption': 'An old green car parked on the side of the street.'},
#  {'image_id': 107990,
#   'id': 5387,
#   'caption': 'A toddler sitting on a motorcycle in a parking lot.'},
#  {'image_id': 61259,
#   'id': 5431,
#   'caption': 'jumbo jet sits on the tarmac while another takes off'},
#  {'image_id': 554037,
#   'id': 5433,
#   'caption': 'asparragus, lemons and a bowl of rice on a counter top'},
#  {'image_id': 285421,
#   'id': 5440,
#   'caption': 'A cat puts her head inside of a toilet. '},
#  {'image_id': 455384,
#   'id': 5458,
#   'caption': 'A large van features an ad for a television show.'},
#  {'image_id': 249352,
#   'id': 5459,
#   'caption': 'A toilet has a rug, and a plunger next to it.'},
#  {'image_id': 57429,
#   'id': 5520,
#   'caption': 'A large jet takes off from an airport runway.'},
#  {'image_id': 71988,
#   'id': 5535,
#   'caption': 'A person on a bench, and one on a wheelchair sitting by a seawall looking out toward the ocean'},
#  {'image_id': 475593,
#   'id': 5537,
#   'caption': 'Women father around a desk and machinery in a factory.'},
#  {'image_id': 407286,
#   'id': 5568,
#   'caption': "Three dogs on the lap of a woman in the driver's seat of a convertible."},
#  {'image_id': 107960,
#   'id': 5580,
#   'caption': "The view from a motorcyclist's point of view, looking down a street."},
#  {'image_id': 5394,
#   'id': 5618,
#   'caption': 'A car modified to be a boat on the water.'},
#  {'image_id': 145523,
#   'id': 5653,
#   'caption': 'A few items sit on top of a toilet in a bathroom stall.'},
#  {'image_id': 567730,
#   'id': 5749,
#   'caption': 'A sign for an Italian restaurant hangs outside a building.'},
#  {'image_id': 107960,
#   'id': 5757,
#   'caption': 'A man rides a motorcycle down an empty street next to houses.'},
#  {'image_id': 143370,
#   'id': 5786,
#   'caption': 'A bathroom with a poster of an ugly face above the toilette.'},
#  {'image_id': 27842,
#   'id': 5795,
#   'caption': 'A long marble like bath room vanity with a stool, two sink basins with mirrors and lights over them'},
#  {'image_id': 6672,
#   'id': 5812,
#   'caption': 'A sink next to a large white door '},
#  {'image_id': 279806,
#   'id': 5835,
#   'caption': 'A dirt bike rider doing a stunt jump in the air'},
#  {'image_id': 491000,
#   'id': 5862,
#   'caption': 'People walking on a city street with light traffic.'},
#  {'image_id': 334015,
#   'id': 5871,
#   'caption': 'A clean, European toilet with toilet paper and cleaning brush.'},
#  {'image_id': 135161,
#   'id': 5884,
#   'caption': 'A bathroom with only a toilet and tub with the wall covered in plastic'},
#  {'image_id': 153184,
#   'id': 5922,
#   'caption': 'A flock of birds sits on top of a large giraffe.'},
#  {'image_id': 59171,
#   'id': 5945,
#   'caption': 'A couple of birds fly through a blue cloudy sky.'},
#  {'image_id': 346071,
#   'id': 5958,
#   'caption': 'Two husky dogs ride in a car with their heads hanging out windows.'},
#  {'image_id': 369826,
#   'id': 6018,
#   'caption': 'A picture advertising Arizona tourism in an airport'},
#  {'image_id': 402514,
#   'id': 6023,
#   'caption': 'A man is playing a fiddle in his kitchen.'},
#  {'image_id': 352538,
#   'id': 6032,
#   'caption': "A woman's purse sitting on a park bench."},
#  {'image_id': 178761,
#   'id': 6079,
#   'caption': 'A dog greets a sheep that is in a sheep pen.'},
#  {'image_id': 193622,
#   'id': 6101,
#   'caption': 'A man sits next to his horse in an alley in costume.'},
#  {'image_id': 61259,
#   'id': 6106,
#   'caption': 'A Virgin Australia airline on the tarmac. '},
#  {'image_id': 554037,
#   'id': 6108,
#   'caption': 'The preparation of salmon, asparagus and lemons. '},
#  {'image_id': 126657,
#   'id': 6127,
#   'caption': 'A group of people are riding motorcycles on a road through a town. '},
#  {'image_id': 358606,
#   'id': 6165,
#   'caption': 'A living room containing a modern fireplace and miscellaneous items '},
#  {'image_id': 567730,
#   'id': 6190,
#   'caption': 'Italian Reaffaello restaurant sign at front of building.'},
#  {'image_id': 119964,
#   'id': 6216,
#   'caption': 'A child with a skateboard sitting on the grass and looking at an empty field'},
#  {'image_id': 285421,
#   'id': 6241,
#   'caption': 'A cat is drinking water out of a toilet.'},
#  {'image_id': 560591,
#   'id': 6269,
#   'caption': 'A toilet in a bathroom that is next to a trash can'},
#  {'image_id': 107960,
#   'id': 6282,
#   'caption': 'The view of the street from the perspective of the rider of a motorcycle'},
#  {'image_id': 79472,
#   'id': 6297,
#   'caption': 'The computer desk in the corner is by a window.'},
#  {'image_id': 145523,
#   'id': 6301,
#   'caption': 'A dirty toilet in a small bathroom.with items on top.'},
#  {'image_id': 267802,
#   'id': 6319,
#   'caption': 'Motorists and bicyclists in a busy city square.'},
#  {'image_id': 508672,
#   'id': 6371,
#   'caption': 'A bicycle parked next to a flooded river'},
#  {'image_id': 104326,
#   'id': 6394,
#   'caption': 'A bright room with green walls and cabinets.'},
#  {'image_id': 162113,
#   'id': 6401,
#   'caption': 'This is a kitchen with dishes and a silver sink.'},
#  {'image_id': 410627,
#   'id': 6444,
#   'caption': 'A man enjoys cooking food in a pan'},
#  {'image_id': 175948,
#   'id': 6475,
#   'caption': 'A narrow bathroom has a white door on its side'},
#  {'image_id': 346071,
#   'id': 6501,
#   'caption': 'Two happy dogs have their head out the car window.'},
#  {'image_id': 400552,
#   'id': 6562,
#   'caption': 'A variety of pots are stored in a nook by a fireplace.'},
#  {'image_id': 315702,
#   'id': 6566,
#   'caption': 'A bathroom vanity with cabinets and basin sink and several grooming products scattered across it'},
#  {'image_id': 218026,
#   'id': 6583,
#   'caption': 'Two horses eating grass near a parking lot. '},
#  {'image_id': 348306,
#   'id': 6588,
#   'caption': 'a welcome to Scotland sign with a bicycle leaning on it'},
#  {'image_id': 189634,
#   'id': 6614,
#   'caption': 'An open box contains an unknown, purple object'},
#  {'image_id': 472598,
#   'id': 6615,
#   'caption': 'An antique, turquoise car is parked at the curb'},
#  {'image_id': 203564,
#   'id': 6637,
#   'caption': 'A bicycle figurine in which the front wheel is replaced with a clock\n'},
#  {'image_id': 193622,
#   'id': 6647,
#   'caption': 'Guy and cow are sitting on the floor '},
#  {'image_id': 238836,
#   'id': 6666,
#   'caption': 'A car is stopped at a red light'},
#  {'image_id': 369826,
#   'id': 6672,
#   'caption': 'A television that is sitting next to signs'},
#  {'image_id': 178761,
#   'id': 6676,
#   'caption': 'Two animals get close through a fence. '},
#  {'image_id': 400552,
#   'id': 6700,
#   'caption': 'A room contains baskets and has a fireplace. '},
#  {'image_id': 475593,
#   'id': 6725,
#   'caption': 'A photo set of two women at work'},
#  {'image_id': 264461,
#   'id': 6752,
#   'caption': 'A bathroom with a traditional toilet next to a floor toilet.'},
#  {'image_id': 162113,
#   'id': 6785,
#   'caption': 'A kitchen with a stove, sick, and dishes'},
#  {'image_id': 203564,
#   'id': 6802,
#   'caption': 'A clock with the appearance of the wheel of a bicycle '},
#  {'image_id': 368402,
#   'id': 6822,
#   'caption': 'A woman is holding a large pan in a kitchen. '},
#  {'image_id': 455384,
#   'id': 6841,
#   'caption': 'A truck with an ad for a television show painted on its side'},
#  {'image_id': 249352,
#   'id': 6842,
#   'caption': 'A small stall with large tiles, a toilet and two plungers'},
#  {'image_id': 567730,
#   'id': 6928,
#   'caption': 'A sign outside of a restaurant for Italian food. '},
#  {'image_id': 334015,
#   'id': 7032,
#   'caption': 'A public toilet stall with toilet paper and a cleaning brush.'},
#  {'image_id': 218026,
#   'id': 7039,
#   'caption': 'Two horses standing in a field across the stre.et from a building'},
#  {'image_id': 264461,
#   'id': 7049,
#   'caption': 'A squat toilet and a Western toilet are next to each other.'},
#  {'image_id': 22793,
#   'id': 7096,
#   'caption': "A men's restroom with a poster of a woman over the urinals."},
#  {'image_id': 527510,
#   'id': 7274,
#   'caption': 'A large military plane parked in the landing area.'},
#  {'image_id': 143370,
#   'id': 7337,
#   'caption': 'A bathroom with a white toilet and sink.'},
#  {'image_id': 455384,
#   'id': 7423,
#   'caption': "A large delivery truck with an advertisement painted on it's side."},
#  {'image_id': 249352,
#   'id': 7424,
#   'caption': 'A small restroom with a single toilet and wooden toilet seat.'},
#  {'image_id': 342387,
#   'id': 7454,
#   'caption': 'A group of people preparing food in a kitchen.'},
#  {'image_id': 141172,
#   'id': 7481,
#   'caption': "A blue door with a painting of a cat's rear end entering thru a cat door."},
#  {'image_id': 548498, 'id': 7522, 'caption': 'A cat is curled up in a bowl'},
#  {'image_id': 488327,
#   'id': 7627,
#   'caption': 'Posted signs point the way through a parking garage.'},
#  {'image_id': 202913,
#   'id': 7637,
#   'caption': 'A half eaten cake with coconut shavings and creme filling.'},
#  {'image_id': 352538,
#   'id': 7670,
#   'caption': "A leather purse laying on it's side on a green metal bench."},
#  {'image_id': 560591,
#   'id': 7679,
#   'caption': 'White toilet by built-in shelves in a tiled bathroom.'},
#  {'image_id': 400552,
#   'id': 7717,
#   'caption': 'A room filled with clutter and a fireplace.'},
#  {'image_id': 540860,
#   'id': 7732,
#   'caption': 'A green car on display next to a busy street.'},
#  {'image_id': 172851,
#   'id': 7748,
#   'caption': 'A large passenger jet taking off from an airport.'},
#  {'image_id': 486194,
#   'id': 7777,
#   'caption': 'Young woman carrying an opened umbrella in a city neighborhood.'},
#  {'image_id': 527510,
#   'id': 7799,
#   'caption': 'A U.S. Air Force plane sits on display.'},
#  {'image_id': 382406,
#   'id': 7911,
#   'caption': 'A woman walks her dog on a city sidewalk.'},
#  {'image_id': 202913,
#   'id': 7979,
#   'caption': 'Half of a cake sits on a plate.'},
#  {'image_id': 5247,
#   'id': 7993,
#   'caption': 'Two people on skis going through the woods.\n'},
#  {'image_id': 135161,
#   'id': 7996,
#   'caption': 'A photograph of a bathroom undergoing some renovations.'},
#  {'image_id': 143370,
#   'id': 8030,
#   'caption': 'Large bathroom with light flowing in the window.'},
#  {'image_id': 573223,
#   'id': 8051,
#   'caption': 'Little girl in blue dress standing in a bathroom. '},
#  {'image_id': 232223,
#   'id': 8083,
#   'caption': 'A fighter jet soars up into a blue sky.'},
#  {'image_id': 61259,
#   'id': 8089,
#   'caption': 'Virgin sponsored airplane parked with a plane leaving in the background.'},
#  {'image_id': 554037,
#   'id': 8091,
#   'caption': 'Cooking table with assorted fish and lemons with asparagus. '},
#  {'image_id': 491000,
#   'id': 8109,
#   'caption': 'A city street with people walking and vehicles on the road.'},
#  {'image_id': 436456,
#   'id': 8113,
#   'caption': 'Two men walking the tarmac of an airport.'},
#  {'image_id': 342387,
#   'id': 8198,
#   'caption': 'Group of people all sorting vegetables in a line.'},
#  {'image_id': 267802,
#   'id': 8206,
#   'caption': 'A crowded city street filled with traffic and bicycles.'},
#  {'image_id': 236148,
#   'id': 8226,
#   'caption': "An older man backing up a truck with a bicycle in it's flat bed."},
#  {'image_id': 133680,
#   'id': 8278,
#   'caption': 'Black man sitting on a bench behind a personal bicycle. '},
#  {'image_id': 139011,
#   'id': 8280,
#   'caption': 'Large group of people waiting for a train.'},
#  {'image_id': 115930,
#   'id': 8299,
#   'caption': 'A group of men standing in front of a bar having a conversation.'},
#  {'image_id': 459912,
#   'id': 8323,
#   'caption': 'Large set of motorcycles all lined up down a street.'},
#  {'image_id': 59171,
#   'id': 8357,
#   'caption': 'Group of three people sailing kites up in the sky. '},
#  {'image_id': 232223,
#   'id': 8380,
#   'caption': 'An old military jet fighter climbing in altitude.'},
#  {'image_id': 279806,
#   'id': 8427,
#   'caption': 'A man riding a dirt bike becomes airborne.'},
#  {'image_id': 358606,
#   'id': 8433,
#   'caption': 'A lit fire place in a living room next to a TV.'},
#  {'image_id': 75663,
#   'id': 8469,
#   'caption': 'A children play area absent of any children.'},
#  {'image_id': 104326,
#   'id': 8479,
#   'caption': 'An empty kitchen area painted green with bulbous lights.'},
#  {'image_id': 573223,
#   'id': 8495,
#   'caption': 'An adorable little girl in a blue dress stands in a restroom.'},
#  {'image_id': 352794,
#   'id': 8503,
#   'caption': 'Fruit in a jar filled with liquid sitting on a wooden table.'},
#  {'image_id': 315702,
#   'id': 8510,
#   'caption': 'A bathroom sink cluttered with multiple personal care items.'},
#  {'image_id': 410627,
#   'id': 8523,
#   'caption': 'A smiling man is cooking in his kitchen.'},
#  {'image_id': 59171,
#   'id': 8612,
#   'caption': 'A beautiful blue and pink sky overlooking the beach.'},
#  {'image_id': 410627,
#   'id': 8649,
#   'caption': 'A man smiles as he stirs his food in the pot.'},
#  {'image_id': 334015,
#   'id': 8724,
#   'caption': 'An empty, clean toilet stall with a stack of toilet paper.'},
#  {'image_id': 175954,
#   'id': 8739,
#   'caption': 'A work station in use inside an office.'},
#  {'image_id': 226419,
#   'id': 8754,
#   'caption': "An airplane with the letters 'MT' on it, flying in the sky."},
#  {'image_id': 484751,
#   'id': 8833,
#   'caption': 'Three computer screens showing a panoramic beach scene.'},
#  {'image_id': 126657,
#   'id': 8866,
#   'caption': 'A group of motorcyclists are driving down the city street.'},
#  {'image_id': 22793,
#   'id': 8881,
#   'caption': 'White tiled bathroom with line of tiles and Asian female poster on the wall'},
#  {'image_id': 267802,
#   'id': 8899,
#   'caption': 'An Asian intersection is full of mopeds and motorcycles.'},
#  {'image_id': 457834,
#   'id': 8986,
#   'caption': 'Elephants are in a long line with people on top of them.'},
#  {'image_id': 412151,
#   'id': 9006,
#   'caption': 'A bicycle store shows two males leaning toward a bike.'},
#  {'image_id': 427091,
#   'id': 9108,
#   'caption': 'City traffic and pedestrians are headed in multiple directions on the street.'},
#  {'image_id': 205577,
#   'id': 9113,
#   'caption': 'This is an apartment kitchen with white cabinets and appliances.'},
#  {'image_id': 369826,
#   'id': 9123,
#   'caption': 'A television is shown in the middle of a baggage claim area.'},
#  {'image_id': 226419,
#   'id': 9174,
#   'caption': 'A very large plane is flying through the sky.'},
#  {'image_id': 133680,
#   'id': 9178,
#   'caption': 'A man is sitting in a busy area with his bike.'},
#  {'image_id': 139011,
#   'id': 9180,
#   'caption': 'People are waiting in a city area to board a bus.'},
#  {'image_id': 32203,
#   'id': 9195,
#   'caption': 'There are some dirt bike riders taking a sharp turn'},
#  {'image_id': 525971,
#   'id': 9250,
#   'caption': 'A large group of motorcycle riders collect in a parking lot. '},
#  {'image_id': 238836,
#   'id': 9264,
#   'caption': 'The car is at the intersection while the sun is setting.'},
#  {'image_id': 238836,
#   'id': 9270,
#   'caption': 'A truck nears a stop light in rainy weather.'},
#  {'image_id': 175954,
#   'id': 9345,
#   'caption': 'A desk inside a library with a computer and several papers on it.'},
#  {'image_id': 354572,
#   'id': 9434,
#   'caption': 'People sitting under an umbrella looking at the scenery.'},
#  {'image_id': 143370,
#   'id': 9509,
#   'caption': 'A small bathroom with a toilet by the window and a pedestal sink with a mirrored medicine cabinet over it'},
#  {'image_id': 419074,
#   'id': 9564,
#   'caption': 'An airplane flying away in the cloudy sky.'},
#  {'image_id': 508672,
#   'id': 9575,
#   'caption': 'A bicycle chained to a rail near a flooded area.'},
#  {'image_id': 185360,
#   'id': 9595,
#   'caption': 'A cow standing next to a damaged car on a dirty lot.'},
#  {'image_id': 484751,
#   'id': 9616,
#   'caption': 'Three computer screens at a desk show a panoramic view of the ocean.'},
#  {'image_id': 175954,
#   'id': 9624,
#   'caption': 'A workstation with a computer, notebook, and papers.'},
#  {'image_id': 436456,
#   'id': 9673,
#   'caption': 'Two men at on an airport tarmac. \n'},
#  {'image_id': 571635,
#   'id': 9687,
#   'caption': 'A little bathrood decorated with many colorful objects'},
#  {'image_id': 486194,
#   'id': 9691,
#   'caption': 'A woman walking while holding up a red umbrella '},
#  {'image_id': 348306,
#   'id': 9696,
#   'caption': 'Bicycle leaning up against a welcome to Scotland sign.'},
#  {'image_id': 135161,
#   'id': 9709,
#   'caption': 'A bathroom being renovated featuring a toilette and shower.'},
#  {'image_id': 178761,
#   'id': 9718,
#   'caption': 'A sheep and a dog touching noses through a fence.'},
#  {'image_id': 573223,
#   'id': 9740,
#   'caption': 'A little girl in a blue dress stands in a bathroom.'},
#  {'image_id': 172851,
#   'id': 9845,
#   'caption': 'A plane that just took off flying from an airport.'},
#  {'image_id': 427091,
#   'id': 9861,
#   'caption': 'A city street busy with many cars driving as well as pedestrians'},
#  {'image_id': 412151,
#   'id': 9891,
#   'caption': 'A man adjust a bicycle in a bike shop with a child.'},
#  {'image_id': 369826,
#   'id': 9897,
#   'caption': 'An airport terminal has a big screen displaying an ad for Arizona.'},
#  {'image_id': 475593,
#   'id': 9977,
#   'caption': 'Women working in a commercial bakery or kitchen.'},
#  {'image_id': 352538,
#   'id': 9986,
#   'caption': 'A purse sits alone on a park bench.'},
#  {'image_id': 321064,
#   'id': 9990,
#   'caption': 'A small wooden table covered with delicious vegetables. '},
#  {'image_id': 175954,
#   'id': 10002,
#   'caption': 'An office desk with a lot of paperwork and a turned on computer'},
#  {'image_id': 263664,
#   'id': 10031,
#   'caption': 'A couple on a motorcycle in front of a bus and a metermaid car'},
#  {'image_id': 525971,
#   'id': 10045,
#   'caption': 'A street full of motorcycles and their riders'},
#  {'image_id': 459912,
#   'id': 10096,
#   'caption': 'A large group of motorcycles lined up on the street.'},
#  {'image_id': 468508,
#   'id': 10100,
#   'caption': 'A red motorcycle parked on a sidewalk near multi-story buildings.'},
#  {'image_id': 321064,
#   'id': 10107,
#   'caption': 'A dining table with a bowl of garlic cloves.'},
#  {'image_id': 348306,
#   'id': 10128,
#   'caption': 'A sign for a village in Scotland with a bicycle in front of it.'},
#  {'image_id': 538092,
#   'id': 10146,
#   'caption': 'A man standing in kitchen surrounded by items.'},
#  {'image_id': 31984,
#   'id': 10176,
#   'caption': 'A model standing next to a scooter in the middle of a room of people'},
#  {'image_id': 202658,
#   'id': 10187,
#   'caption': 'A toilette with a pink hello kitty toilette seat cover.'},
#  {'image_id': 202658,
#   'id': 10208,
#   'caption': 'A toilet with a Hello Kitty seat sitting in a room.'},
#  {'image_id': 175948,
#   'id': 10216,
#   'caption': 'Rather narrow bath room that appears to be being remodeled.'},
#  {'image_id': 135161,
#   'id': 10243,
#   'caption': 'A bathroom in the middle of a reconstruction phase.'},
#  {'image_id': 400552,
#   'id': 10264,
#   'caption': 'A small living room with a fireplace and work baskets.\n'},
#  {'image_id': 264461,
#   'id': 10325,
#   'caption': 'Mans bathroom with two visible fixtures, trash basket and plunger in sight.'},
#  {'image_id': 368402,
#   'id': 10359,
#   'caption': 'A woman cooking in a kitchen with granite counters.'},
#  {'image_id': 368402,
#   'id': 10533,
#   'caption': 'A woman cooking in her kitchen with a black pan.'},
#  {'image_id': 346071,
#   'id': 10539,
#   'caption': 'Some dogs stick their heads out the car window.'},
#  {'image_id': 352794,
#   'id': 10570,
#   'caption': 'Some yellow objects are floating in red liquid in a jar.'},
#  {'image_id': 322791,
#   'id': 10581,
#   'caption': 'An airplane is doing tricks and emitting smoke.'},
#  {'image_id': 491000,
#   'id': 10614,
#   'caption': 'A scenic photograph of an urban street with people and traffic.'},
#  {'image_id': 295768,
#   'id': 10625,
#   'caption': 'Computer monitor and accesories sitting on a desk.'},
#  {'image_id': 525971,
#   'id': 10657,
#   'caption': 'Several bikers are lined up in a parking lot.'},
#  {'image_id': 229067,
#   'id': 10667,
#   'caption': 'A group of people skiing down a snow covered slope.'},
#  {'image_id': 156324,
#   'id': 10668,
#   'caption': 'A woman takes a selfie in front of a bathroom mirror.'},
#  {'image_id': 508605,
#   'id': 10673,
#   'caption': 'Boy rides skateboard and does trick over stairs.'},
#  {'image_id': 268224,
#   'id': 10682,
#   'caption': 'Three young people in a kitchen pointing to a pizza.'},
#  {'image_id': 354572,
#   'id': 10718,
#   'caption': 'A person with a colorful umbrella sits on a fountain.'},
#  {'image_id': 206260,
#   'id': 10725,
#   'caption': 'Assorted flavored donuts being grabbed by multiple hands.'},
#  {'image_id': 489528,
#   'id': 10730,
#   'caption': 'An outside doorway to a restroom showing a destroyed wall and damaged floor.'},
#  {'image_id': 205577,
#   'id': 10733,
#   'caption': 'A shot of a kitchen with a microwave, sink, dishwasher, and refrigerator. '},
#  {'image_id': 229067,
#   'id': 10823,
#   'caption': 'Six people in snow field with ski equipment.'},
#  {'image_id': 156324,
#   'id': 10824,
#   'caption': 'Woman taking picture of self in bathroom mirror.'},
#  {'image_id': 218026,
#   'id': 10831,
#   'caption': 'Two mules eating grass in a parking lot in front of a hotel. '},
#  {'image_id': 238836,
#   'id': 10845,
#   'caption': 'A car is at a red light in the rain.'},
#  {'image_id': 27842,
#   'id': 10865,
#   'caption': 'A double sink with mirrors and a stool underneath it.'},
#  {'image_id': 263664,
#   'id': 10940,
#   'caption': 'A busy city street with a bus, taxi, and motorcycle.'},
#  {'image_id': 450308,
#   'id': 10947,
#   'caption': 'A man stands with his bike in ankle deep water in a flooded city.'},
#  {'image_id': 22793,
#   'id': 10951,
#   'caption': 'A mens restroom is lined up with urinals.'},
#  {'image_id': 175948,
#   'id': 10960,
#   'caption': 'Unfinished bathroom with broken toilet next to a bookshelf.'},
#  {'image_id': 342387,
#   'id': 10973,
#   'caption': 'Six different people in aprons and hats preparing vegetables'},
#  {'image_id': 279806,
#   'id': 10986,
#   'caption': 'A motorcyclist is in mid air hanging on to the handlebars.'},
#  {'image_id': 446409,
#   'id': 11053,
#   'caption': 'A tabby cat laying on a cat scratcher in front of a bicycle wheel. '},
#  {'image_id': 420958,
#   'id': 11083,
#   'caption': 'This a view from an airplane of the landscape below.'},
#  {'image_id': 571635,
#   'id': 11109,
#   'caption': 'A small bathroom containing a toilet and sink. '},
#  {'image_id': 523400,
#   'id': 11127,
#   'caption': 'A bathroom with double sinks, mirrors, toilet and towel racks.'},
#  {'image_id': 172851,
#   'id': 11138,
#   'caption': 'The airplane has begun its ascent in the skies.'},
#  {'image_id': 369826,
#   'id': 11142,
#   'caption': 'A flat screen TV with a picture of a person jumping on it.'},
#  {'image_id': 507362,
#   'id': 11200,
#   'caption': 'City street at night with several stop lights.'},
#  {'image_id': 40986,
#   'id': 11208,
#   'caption': 'Raw cookies in a pan on the counter and baked cookies in a pan on the stove.'},
#  {'image_id': 525971,
#   'id': 11221,
#   'caption': 'Motorcyclist meeting with one another before a ride.'},
#  {'image_id': 538092,
#   'id': 11235,
#   'caption': 'A kitchen area with a cooler and container stacked on the floor and a man getting an item out of a cabinet.'},
#  {'image_id': 59171,
#   'id': 11252,
#   'caption': 'Group of people are flying kites on the beach.'},
#  {'image_id': 27842,
#   'id': 11279,
#   'caption': 'There are two sinks in the clean bathroom.'},
#  {'image_id': 264461,
#   'id': 11315,
#   'caption': 'A toilet stall, complete with two clean toilets.'},
#  {'image_id': 141172,
#   'id': 11318,
#   'caption': 'A blue door with a picture of a cat door with cats backside hanging out on it.'},
#  {'image_id': 61259,
#   'id': 11329,
#   'caption': 'One airplane is taking off from an airport while others are parked.'},
#  {'image_id': 554037,
#   'id': 11331,
#   'caption': 'A kitchen counter with cutting board, knife and food.'},
#  {'image_id': 321064,
#   'id': 11460,
#   'caption': 'A kitchen table with a juicer and vegetable on it.'},
#  {'image_id': 236148,
#   'id': 11508,
#   'caption': 'A man looking out the back window of his truck.'},
#  {'image_id': 488327,
#   'id': 11512,
#   'caption': 'Three traffic signs at the entrance of a parking garage. '},
#  {'image_id': 571635,
#   'id': 11517,
#   'caption': 'Bathroom containing a toilet, a sink and a wicker basket.'},
#  {'image_id': 107960,
#   'id': 11523,
#   'caption': 'A motorcycle moves forward down an empty street.'},
#  {'image_id': 400552,
#   'id': 11542,
#   'caption': 'A room with a fir place and several baskets and a bench in the background.'},
#  {'image_id': 523400,
#   'id': 11574,
#   'caption': 'A fancy bathroom with his and her mirrors and sinks next to a toilette.'},
#  {'image_id': 420958,
#   'id': 11605,
#   'caption': 'A view from a window on board an airplane flying in the sky.'},
#  {'image_id': 141172,
#   'id': 11615,
#   'caption': 'A picture of a cat door is on the bottom corner of a blue door.'},
#  {'image_id': 8045,
#   'id': 11673,
#   'caption': 'Tub and shower on platform in modern tiled bathroom.'},
#  {'image_id': 264461,
#   'id': 11702,
#   'caption': 'A bathroom with an odd toilette next to a normal toilette.'},
#  {'image_id': 322791,
#   'id': 11724,
#   'caption': 'An aerial stunt plane in a climb with smoke coming out of the back.'},
#  {'image_id': 525971,
#   'id': 11740,
#   'caption': 'There is no picture or image sorry sorry'},
#  {'image_id': 508672,
#   'id': 11777,
#   'caption': 'A bicycle leans against a fence near some flood waters.'},
#  {'image_id': 484751,
#   'id': 11821,
#   'caption': 'A desk with multiple computer screens forming one large screen.'},
#  {'image_id': 529691,
#   'id': 11842,
#   'caption': 'A row of park benches on the side of a green grassy hill. '},
#  {'image_id': 486194,
#   'id': 11860,
#   'caption': 'A beautiful young lady walking in the rain while holding an umbrella.'},
#  {'image_id': 202658,
#   'id': 11897,
#   'caption': 'A broken toilet bowl with  a Hello Kitty toilet seat cover.'},
#  {'image_id': 482597,
#   'id': 11931,
#   'caption': 'A man in an ATV is moving the cows along.'},
#  {'image_id': 205577,
#   'id': 11933,
#   'caption': 'A kitchen with a refrigerator, microwave, dishwasher and sink.'},
#  {'image_id': 82673,
#   'id': 11969,
#   'caption': 'A scooter is parked behind a red car.'},
#  {'image_id': 540860,
#   'id': 11986,
#   'caption': 'A sculpture of a green hot rod on a city sidewalk'},
#  {'image_id': 51191,
#   'id': 11990,
#   'caption': 'The view of a large bathroom with a walk in closet.'},
#  {'image_id': 488327,
#   'id': 12007,
#   'caption': 'Three road signs posted in a parking garage.'},
#  {'image_id': 295768,
#   'id': 12014,
#   'caption': 'An Apple computer on a table next to an iPhone and an iPad.'},
#  {'image_id': 8045,
#   'id': 12111,
#   'caption': 'A bathroom with a shower combination tub and sink.'},
#  {'image_id': 27842,
#   'id': 12137,
#   'caption': 'A bathroom with his and her mirrors and sinks.'},
#  {'image_id': 115930,
#   'id': 12169,
#   'caption': 'Restaurant staff taking a break near the bar.'},
#  {'image_id': 75663,
#   'id': 12189,
#   'caption': 'A craft supply room with craft supplies and containers.'},
#  {'image_id': 354572,
#   'id': 12197,
#   'caption': 'A man with a colored umbrella sits on a monument.'},
#  {'image_id': 249371,
#   'id': 12217,
#   'caption': 'Many sheep grazing in a large, green pasture.'},
#  {'image_id': 408364,
#   'id': 12261,
#   'caption': "A young man standing next to a race car with the red sox logo on it's hood."},
#  {'image_id': 267862,
#   'id': 12312,
#   'caption': 'A guy sitting on his motorcycle while a woman stands beside him'},
#  {'image_id': 115930,
#   'id': 12313,
#   'caption': 'Several men having a conversation at a restaurant.'},
#  {'image_id': 232223,
#   'id': 12349,
#   'caption': 'A fighter jet flying through the sky with smoke coming off of it.'},
#  {'image_id': 402514,
#   'id': 12356,
#   'caption': 'A man plays the violin in a home.'},
#  {'image_id': 482597,
#   'id': 12426,
#   'caption': 'A man is riding a tractor following some cows.'},
#  {'image_id': 6672,
#   'id': 12427,
#   'caption': 'A door for exiting and entering the house in the kitchen.'},
#  {'image_id': 436456,
#   'id': 12433,
#   'caption': 'Two young men walking down a runway toward an airplane.'},
#  {'image_id': 540860,
#   'id': 12496,
#   'caption': 'A sculpture of a hot rod sitting on a sidewalk.'},
#  {'image_id': 536321,
#   'id': 12500,
#   'caption': 'An adorable caleco cat sitting underneath a bicycle.'},
#  {'image_id': 148272,
#   'id': 12501,
#   'caption': 'An adorable cat attempts to hide in a purse to steal the persons identity.'},
#  {'image_id': 279806,
#   'id': 12540,
#   'caption': 'A person performs a stunt jump on a motorcycle.'},
#  {'image_id': 412151,
#   'id': 12564,
#   'caption': 'The bike shop employee is helping a customer. '},
#  {'image_id': 36450,
#   'id': 12570,
#   'caption': 'A very big teddy bear is next to a woman.'},
#  {'image_id': 249371,
#   'id': 12583,
#   'caption': 'Many sheep graze in a grassy pasture in a valley. '},
#  {'image_id': 523400,
#   'id': 12597,
#   'caption': 'A bathroom with a double sink and mirrors.'},
#  {'image_id': 138599,
#   'id': 12627,
#   'caption': 'A BMW motor cycle parked next to shrub..'},
#  {'image_id': 206260,
#   'id': 12639,
#   'caption': 'A group of people with a bunch of doughnuts. '},
#  {'image_id': 358606,
#   'id': 12675,
#   'caption': 'A brick fireplace with fire adorned with knick-knacks.'},
#  {'image_id': 82673,
#   'id': 12713,
#   'caption': 'A small car parked in by a vespa.'},
#  {'image_id': 354572,
#   'id': 12731,
#   'caption': 'A man sis on a public area while holding an umbrella.'},
# ...
#  {'image_id': 75118,
#   'id': 24200,
#   'caption': 'A red and white jet plane releasing chemtrails.'},
#  {'image_id': 428769,
#   'id': 24202,
#   'caption': 'A black car withe license plate SUPABAAD parked next to a parking meter.'},
#  {'image_id': 370462,
#   'id': 24205,
#   'caption': 'A ski lodge covered in snow next a mountain filled with trees.'},
#  {'image_id': 69236,
#   'id': 24239,
#   'caption': 'A park and walkway lined with benches and bushes.'},
#  {'image_id': 364113,
#   'id': 24267,
#   'caption': 'Two people riding different colored horses down a dirty road.'},
#  {'image_id': 104381,
#   'id': 24278,
#   'caption': 'A car sitting at a stop light at dusk.'},
#  {'image_id': 322604,
#   'id': 24314,
#   'caption': 'People on motorcycles riding in the street in a parade.'},
#  {'image_id': 43098,
#   'id': 24328,
#   'caption': 'A man walking down the sidewalk, and a blue briefcase in front of a post.'},
#  {'image_id': 231846,
#   'id': 24365,
#   'caption': 'A brown cat sitting in a bathroom sink.'},
#  {'image_id': 301574,
#   'id': 24383,
#   'caption': 'Three people on red motorcycles stopped and showing off.'},
#  {'image_id': 349804,
#   'id': 24402,
#   'caption': 'A monument depicting three fighter planes attached to the ground.'},
#  {'image_id': 8180,
#   'id': 24474,
#   'caption': 'A jet airliner waits its turn on the runway.'},
#  {'image_id': 79920,
#   'id': 24537,
#   'caption': 'A living room with a large tv and pictures all around.'},
#  {'image_id': 93959,
#   'id': 24539,
#   'caption': 'There is nobody in the kitchen right now.'},
#  {'image_id': 408364,
#   'id': 24546,
#   'caption': 'A young boy  standing by a Red Sox car wearing Red Sox shirt and visor'},
#  {'image_id': 30423,
#   'id': 24591,
#   'caption': 'Four giraffes are standing in front of some trees.'},
#  {'image_id': 498547,
#   'id': 24663,
#   'caption': 'A kitchen with a large stove and a lot of pots.'},
#  {'image_id': 468858,
#   'id': 24664,
#   'caption': 'The living room is empty and the television is turned off.'},
#  {'image_id': 56070,
#   'id': 24667,
#   'caption': 'A black and orange motorcycle on a sidewalk.'},
#  {'image_id': 494629,
#   'id': 24681,
#   'caption': 'A man sits on a toilet while working on his computer at his desk.'},
#  {'image_id': 61422,
#   'id': 24687,
#   'caption': 'A bathroom with a sink and a toilet. '},
#  {'image_id': 548706,
#   'id': 24744,
#   'caption': 'A bathroom with checkered tile and maroon towels.'},
#  {'image_id': 385757,
#   'id': 24779,
#   'caption': 'A car coming to a stop sign as seen from inside the car.'},
#  {'image_id': 11334,
#   'id': 24785,
#   'caption': 'An ornate building has a clock tower near by.'},
#  {'image_id': 146961,
#   'id': 24804,
#   'caption': 'A man is cooking in a crowded kitchen.'},
#  {'image_id': 155997,
#   'id': 24847,
#   'caption': 'A dog in a basket being carried by its owner.'},
#  {'image_id': 306313,
#   'id': 24930,
#   'caption': 'A kitchen that features and oven that has a light turned on in it.'},
#  {'image_id': 9288,
#   'id': 24948,
#   'caption': 'A toilet in a restroom next to a toilet paper dispenser'},
#  {'image_id': 510992,
#   'id': 24953,
#   'caption': 'a white stoves burners with a green timer and some decorations'},
#  {'image_id': 278237,
#   'id': 24954,
#   'caption': 'a bus and two cars are going down a two way street'},
#  {'image_id': 555472,
#   'id': 24971,
#   'caption': 'An elephant crossing the road in front of an SUV.\n'},
#  {'image_id': 175024,
#   'id': 24978,
#   'caption': 'A person on a motorcycle with a stuffed animal on back.'},
#  {'image_id': 262594,
#   'id': 24983,
#   'caption': 'A small group of people standing around a small motor bike.'},
#  {'image_id': 79920,
#   'id': 24993,
#   'caption': 'A flat screen TV sitting next to a fireplace in a living room.'},
#  {'image_id': 93959,
#   'id': 24998,
#   'caption': 'A kitchen with lots of cupboards and counter space.'},
#  {'image_id': 136783,
#   'id': 25006,
#   'caption': 'A rock wall next to a green tiled room.'},
#  {'image_id': 301574,
#   'id': 25040,
#   'caption': 'Three red motorcycles with riders in protective gear are on the street.'},
#  {'image_id': 372413,
#   'id': 25051,
#   'caption': 'Man hangs off side of motorcycle during race as spectators look on. '},
#  {'image_id': 175024,
#   'id': 25062,
#   'caption': 'A motorcyclist riding with a stuffed animal attached to the back.'},
#  {'image_id': 120157,
#   'id': 25069,
#   'caption': 'A toilet bowl with no toilet seat in a restroom'},
#  {'image_id': 5879,
#   'id': 25099,
#   'caption': 'Two people riding their bikes in the street.'},
#  {'image_id': 548706,
#   'id': 25125,
#   'caption': 'A bathroom with a checkered black and white tile floor'},
#  {'image_id': 555472,
#   'id': 25148,
#   'caption': 'Elephant walking through the middle of the road in front of a car. '},
#  {'image_id': 555472,
#   'id': 25154,
#   'caption': 'An elephant crossing the road in front of a car.'},
#  {'image_id': 39430,
#   'id': 25160,
#   'caption': 'Two sheep peeking over the wall at something.'},
#  {'image_id': 193680,
#   'id': 25164,
#   'caption': 'Full grown cat laying down and sleeping on top of a car. '},
#  {'image_id': 30423,
#   'id': 25206,
#   'caption': 'Four giraffes standing in front of trees on a grassy field. '},
#  {'image_id': 322604,
#   'id': 25229,
#   'caption': 'Ladies riding down the street on motorcycles as others look on.'},
#  {'image_id': 565635,
#   'id': 25232,
#   'caption': 'two lines of motorcycles driving down the road while a crowd watches'},
#  {'image_id': 561780,
#   'id': 25255,
#   'caption': 'A group of older people sitting on a park bench with a dog on a leash.'},
#  {'image_id': 262594,
#   'id': 25262,
#   'caption': 'A man standing next to a motorcycle on asphalt.'},
#  {'image_id': 90732,
#   'id': 25277,
#   'caption': 'A girl in a kitchen on a booster stool washing dishes.'},
#  {'image_id': 230600,
#   'id': 25288,
#   'caption': 'A toilet on the outside of a building next to a parking meter.'},
#  {'image_id': 14297,
#   'id': 25327,
#   'caption': 'A boat home sitting on a river bay.'},
#  {'image_id': 215708,
#   'id': 25388,
#   'caption': 'People standing around a cake with candles in it.'},
#  {'image_id': 231846,
#   'id': 25412,
#   'caption': 'An orange tabby cat lying in a bathroom sink.'},
#  {'image_id': 43098,
#   'id': 25414,
#   'caption': 'A blue suitcase is leaning against a post on the street while a man walks by.'},
#  {'image_id': 237920,
#   'id': 25487,
#   'caption': 'The front view of a building that has a bench, and chairs located in front. '},
#  {'image_id': 193680,
#   'id': 25491,
#   'caption': 'A cat napping on a red car in a driveway.'},
#  {'image_id': 241876,
#   'id': 25505,
#   'caption': 'A blurry picture of a cat standing on a toilet.'},
#  {'image_id': 34474,
#   'id': 25506,
#   'caption': 'The interior of a house with lots of wood detailing.'},
#  {'image_id': 43098,
#   'id': 25507,
#   'caption': 'A man walking past a suitcase and street lamp'},
#  {'image_id': 69293,
#   'id': 25511,
#   'caption': 'The bathroom toilet with the cover up, sink, and bathroom items are shown.'},
#  {'image_id': 145523,
#   'id': 25516,
#   'caption': 'A photo of a toilet with items on the tank.'},
#  {'image_id': 349344,
#   'id': 25581,
#   'caption': 'A car show features a yellow hot wheels car.'},
#  {'image_id': 193680,
#   'id': 25614,
#   'caption': 'A orange cat taking a nap on top of a car.'},
#  {'image_id': 56070,
#   'id': 25651,
#   'caption': 'A shiny motorcycle is parked on a city sidewalk.'},
#  {'image_id': 81505,
#   'id': 25689,
#   'caption': 'An american eagle commercial plane flying in the sky'},
#  {'image_id': 81505,
#   'id': 25692,
#   'caption': 'A commercial airplane flies through the sky to its destination. '},
#  {'image_id': 306313,
#   'id': 25701,
#   'caption': 'The front view of the stove built within the counter. '},
#  {'image_id': 565635,
#   'id': 25712,
#   'caption': 'A lot of spectators  watch a motorcade on Washington D.C. '},
#  {'image_id': 262594,
#   'id': 25733,
#   'caption': 'A person holding upright an older motorcycle that looks to be retrofitted.'},
#  {'image_id': 241876,
#   'id': 25766,
#   'caption': 'A cat standing on the toilet bowl seat'},
#  {'image_id': 34474,
#   'id': 25767,
#   'caption': 'A bathroom with dark wooden fixtures  and shelving'},
#  {'image_id': 69293,
#   'id': 25778,
#   'caption': 'a bathroom with a sink and a toilet near a scale'},
#  {'image_id': 123843,
#   'id': 25802,
#   'caption': 'The view of the shower, sink, and towel rack.'},
#  {'image_id': 369979,
#   'id': 25816,
#   'caption': 'Several pieces of art and a painting on display'},
#  {'image_id': 322604,
#   'id': 25844,
#   'caption': 'a gay parade with some lesbians on motorcycles'},
#  {'image_id': 193680,
#   'id': 25851,
#   'caption': 'A fluffy cat sleeping on top of a red car.'},
#  {'image_id': 32054,
#   'id': 25906,
#   'caption': 'a dog standing near a street sign on a dirt road'},
#  {'image_id': 525667,
#   'id': 25919,
#   'caption': 'A group of women are describing a new setup for a building plan'},
#  {'image_id': 364113,
#   'id': 25935,
#   'caption': 'Two people riding horses along  a trail'},
#  {'image_id': 494629,
#   'id': 26049,
#   'caption': 'A man sitting on a toilet in front of the computer.'},
#  {'image_id': 555472,
#   'id': 26063,
#   'caption': 'Elephant crossing road in front of SUV vehicle,'},
#  {'image_id': 21711,
#   'id': 26085,
#   'caption': 'Motorcyclists and a bicycle are parked on a yard.'},
#  {'image_id': 30423,
#   'id': 26148,
#   'caption': 'Several giraffe somewhat distant standing on the edge of a wooded area.'},
#  {'image_id': 106900,
#   'id': 26216,
#   'caption': 'A man and a woman walking in the snow with a dog. '},
#  {'image_id': 325374,
#   'id': 26256,
#   'caption': 'A sheep in the field being shorn by a man.'},
#  {'image_id': 237920,
#   'id': 26273,
#   'caption': 'A brightly colored store front with benches and chairs.'},
#  {'image_id': 175024,
#   'id': 26277,
#   'caption': 'A person in full leather riding a motorcycle with a stuff animal on the back.'},
#  {'image_id': 349344,
#   'id': 26337,
#   'caption': 'People at a auto show viewing very fancy cars.'},
#  {'image_id': 93959,
#   'id': 26429,
#   'caption': 'A nicely decorated kitchen area with white cabinets '},
#  {'image_id': 281950,
#   'id': 26435,
#   'caption': 'A toilet next to a wall in the bathroom. '},
#  {'image_id': 293153,
#   'id': 26446,
#   'caption': 'The sightseeing boat streams along the river joined by a plane'},
#  {'image_id': 32054,
#   'id': 26455,
#   'caption': 'A thin dog is standing by a marker in the road. '},
#  {'image_id': 21711,
#   'id': 26460,
#   'caption': 'A couple people on motocross bikes, and a couple other people standing around.'},
#  {'image_id': 281950,
#   'id': 26492,
#   'caption': 'A toilet in a bathroom with stone walls.'},
#  {'image_id': 436972,
#   'id': 26501,
#   'caption': 'A police man standing on tip of his motorcycle.'},
#  {'image_id': 300216,
#   'id': 26661,
#   'caption': 'a white bathroom a sink and a brown mirror'},
#  {'image_id': 61422,
#   'id': 26670,
#   'caption': 'A modern and clean bathroom with a big sink.'},
#  {'image_id': 293153,
#   'id': 26704,
#   'caption': 'a photo of  a boat with an airplane in back'},
#  {'image_id': 146961,
#   'id': 26709,
#   'caption': 'A man cooking in the kitchen in front of the stove. '},
#  {'image_id': 127585,
#   'id': 26728,
#   'caption': 'A room with a chair and couch and multiple books.'},
#  {'image_id': 155997,
#   'id': 26740,
#   'caption': 'A man riding a bike with a wooden trainer attached and a dog riding in it.'},
#  {'image_id': 312724,
#   'id': 26750,
#   'caption': 'A herd of of wild animals walking around a field surrounded by forest.'},
#  {'image_id': 20788,
#   'id': 26755,
#   'caption': 'A woman hovering over food on a wooden table.'},
#  {'image_id': 369763,
#   'id': 26760,
#   'caption': 'A man and police officer on the sidewalk next to a motorcycle.'},
#  {'image_id': 443351,
#   'id': 26767,
#   'caption': 'Two motorcycles parked on black pavement side by side.'},
#  {'image_id': 364113,
#   'id': 26781,
#   'caption': 'Two people riding horses along a scenic trail.'},
#  {'image_id': 75118,
#   'id': 26813,
#   'caption': 'a decorated jet plane flying in the sky leaving a traill of smoke'},
#  {'image_id': 19523,
#   'id': 26822,
#   'caption': 'a boy and girl are putting their bicycles on the front of a bus'},
#  {'image_id': 424378,
#   'id': 26857,
#   'caption': 'A man with glasses riding in a car with an adorable dog in the backseat.'},
#  {'image_id': 400456,
#   'id': 26881,
#   'caption': 'A man riding on the back of a brown horse in front of a truck.'},
#  {'image_id': 14297,
#   'id': 26920,
#   'caption': 'A house boat with many bikes on a riverbank.'},
#  {'image_id': 300216,
#   'id': 26952,
#   'caption': 'A bathroom sink underneath a mirror and tooth brushes.'},
#  {'image_id': 564911,
#   'id': 27045,
#   'caption': 'An airplane that is on the landing strip.'},
#  {'image_id': 525667,
#   'id': 27065,
#   'caption': 'a group of people in a field of grass near a building'},
#  {'image_id': 19523,
#   'id': 27068,
#   'caption': 'A man with a bicycle stands in front of a bus.'},
#  {'image_id': 155997,
#   'id': 27076,
#   'caption': 'A man on a bike pulling a dog in a cart.'},
#  {'image_id': 281950,
#   'id': 27101,
#   'caption': 'A toilet and plunger in a rustic bathroom.'},
#  {'image_id': 424378,
#   'id': 27145,
#   'caption': 'A man driving with his dog in the back seat.'},
#  {'image_id': 445002,
#   'id': 27148,
#   'caption': 'A bathroom with two sinks and an enclosed shower.'},
#  {'image_id': 262594,
#   'id': 27152,
#   'caption': 'A person standing beside a unique moped on a street.'},
#  {'image_id': 186697,
#   'id': 27174,
#   'caption': 'A peson riding a bike down a long narrow road.'},
#  {'image_id': 489528,
#   'id': 27212,
#   'caption': 'A broken door frame showing a a bathroom with a cement floor and a broken back wall'},
#  {'image_id': 260409,
#   'id': 27224,
#   'caption': 'A motorcyclist in his helmet parked along side a road near the ocean'},
#  {'image_id': 301574,
#   'id': 27251,
#   'caption': 'Three drivers wearing helmets sitting on their motorcycles.'},
#  {'image_id': 69293,
#   'id': 27254,
#   'caption': 'A very small brown colored bathroom with a white toilet.'},
#  {'image_id': 549386,
#   'id': 27289,
#   'caption': 'Two people stand outside of a very old building.'},
#  {'image_id': 120157,
#   'id': 27337,
#   'caption': 'A toilet in a restroom next to a trash can.'},
#  {'image_id': 237920,
#   'id': 27341,
#   'caption': 'Benches and chairs set outside a building with cathedral doors.'},
#  {'image_id': 564911,
#   'id': 27411,
#   'caption': 'Big commercial airplane getting ready to take off.'},
#  {'image_id': 104381,
#   'id': 27434,
#   'caption': 'The a car that is stopped at a red light at an intersection'},
#  {'image_id': 293153,
#   'id': 27439,
#   'caption': 'A ferry moved through the water while an airplane flies overhead.'},
#  {'image_id': 69236,
#   'id': 27482,
#   'caption': 'Two back to back wooden benches next to a shrub near a stone walkway'},
#  {'image_id': 428769,
#   'id': 27484,
#   'caption': 'A mercedez benz car is parked next to a parking meter.'},
#  {'image_id': 370210,
#   'id': 27488,
#   'caption': 'Two adorable dogs hanging out of a car door window.'},
#  {'image_id': 531111,
#   'id': 27489,
#   'caption': 'A bathroom with a checkered floor and an enclosed shower.'},
#  {'image_id': 193680,
#   'id': 27564,
#   'caption': 'An orange cat sleeping on top of a red car.'},
#  {'image_id': 123843,
#   'id': 27671,
#   'caption': 'A white and bright bathroom with silver fixtures.'},
#  {'image_id': 385757,
#   'id': 27683,
#   'caption': 'Picture taken inside a car at a stop sign of fall foliage.'},
#  {'image_id': 336384,
#   'id': 27692,
#   'caption': 'An airliner taking off from an airport runway.'},
#  {'image_id': 443351,
#   'id': 27721,
#   'caption': 'Two different motorcycles angle parked on a street.'},
#  {'image_id': 312724,
#   'id': 27755,
#   'caption': 'Zebras, giraffes and kudus on the run across a plain.'},
#  {'image_id': 436972,
#   'id': 27827,
#   'caption': 'The cop was standing on his bike for fun.'},
#  {'image_id': 230600,
#   'id': 27832,
#   'caption': 'A toilet sitting on the street next to a parking machine.'},
#  {'image_id': 251075,
#   'id': 27841,
#   'caption': 'A bathroom with a tan sink and white toliet.'},
#  ...]

# %%
# Group all captions together having the same image ID.
image_path_to_caption = collections.defaultdict(list)
for val in annotations['annotations']:
    
    caption = f"<start> {val['caption']} <end>"
    #image_path = PATH + 'COCO_train2014_' + '%012d.jpg' % (val['image_id'])
    image_path = image_folder + '%012d.jpg' % (val['image_id'])
    image_path_to_caption[image_path].append(caption)

# %%
'%012d.jpg' % 12345
# Out:
# '000000012345.jpg'

# %%
image_path_to_caption
# Out:
# defaultdict(list,
#             {'D://Panoptic_2017/train2017/000000203564.jpg': ['<start> A bicycle replica with a clock as the front wheel. <end>',
#               '<start> The bike has a clock as a tire. <end>',
#               '<start> A black metal bicycle with a clock inside the front wheel. <end>',
#               '<start> A bicycle figurine in which the front wheel is replaced with a clock\n <end>',
#               '<start> A clock with the appearance of the wheel of a bicycle  <end>'],
#              'D://Panoptic_2017/train2017/000000322141.jpg': ['<start> A room with blue walls and a white sink and door. <end>',
#               '<start> Blue and white color scheme in a small bathroom. <end>',
#               '<start> This is a blue and white bathroom with a wall sink and a lifesaver on the wall. <end>',
#               '<start> A blue boat themed bathroom with a life preserver on the wall <end>',
#               '<start> A bathroom with walls that are painted baby blue. <end>'],
#              'D://Panoptic_2017/train2017/000000016977.jpg': ['<start> A car that seems to be parked illegally behind a legally parked car <end>',
#               '<start> two cars parked on the sidewalk on the street <end>',
#               '<start> City street with parked cars and a bench. <end>',
#               '<start> Cars try to maneuver into parking spaces along a densely packed city street.  <end>',
#               '<start> A couple of cars parked in a busy street sidewalk. <end>'],
#              'D://Panoptic_2017/train2017/000000106140.jpg': ['<start> A large passenger airplane flying through the air. <end>',
#               '<start> There is a GOL plane taking off in a partly cloudy sky. <end>',
#               '<start> An airplane that is, either, landing or just taking off. <end>',
#               '<start> An red and white airplane is in the cloudy sky. <end>',
#               '<start> A passenger plane taking off into the sky.  <end>'],
#              'D://Panoptic_2017/train2017/000000571635.jpg': ['<start> A bathroom with a toilet, sink, and shower. <end>',
#               '<start> A full bathroom with a wicker laundry basket. <end>',
#               '<start> A little bathrood decorated with many colorful objects <end>',
#               '<start> A small bathroom containing a toilet and sink.  <end>',
#               '<start> Bathroom containing a toilet, a sink and a wicker basket. <end>'],
#              'D://Panoptic_2017/train2017/000000301837.jpg': ['<start> A long empty, minimal modern skylit home kitchen. <end>',
#               '<start> A picture of a modern looking kitchen area\n <end>',
#               '<start> A narrow kitchen ending with a chrome refrigerator. <end>',
#               '<start> A narrow kitchen is decorated in shades of white, gray, and black. <end>',
#               '<start> a room that has a stove and a icebox in it <end>'],
#              'D://Panoptic_2017/train2017/000000315702.jpg': ['<start> A bathroom sink with toiletries on the counter. <end>',
#               '<start> A bathroom sink and various personal hygiene items. <end>',
#               '<start> A messy bathroom countertop perched atop black cabinetry. <end>',
#               '<start> A bathroom vanity with cabinets and basin sink and several grooming products scattered across it <end>',
#               '<start> A bathroom sink cluttered with multiple personal care items. <end>'],
#              'D://Panoptic_2017/train2017/000000189634.jpg': ['<start> This is an open box containing four cucumbers. <end>',
#               '<start> An open food container box with four unknown food items. <end>',
#               '<start> A small box filled with four green vegetables.  <end>',
#               '<start> An opened box of four chocolate bananas.  <end>',
#               '<start> An open box contains an unknown, purple object <end>'],
#              'D://Panoptic_2017/train2017/000000472598.jpg': ['<start> An old-fashioned green station wagon is parked on a shady driveway. <end>',
#               '<start> An old teal colored car parked on the street. <end>',
#               '<start> A classic car sitting beside the road with a surfboard on top.  <end>',
#               '<start> An old green car parked on the side of the street. <end>',
#               '<start> An antique, turquoise car is parked at the curb <end>'],
#              'D://Panoptic_2017/train2017/000000162113.jpg': ['<start> A gas stove next to a stainless steel kitchen sink and countertop. <end>',
#               '<start> A kitchen stove, sink, and counter with stuff on it. <end>',
#               '<start> A kitchen with a stove, sink, and drying area.  <end>',
#               '<start> This is a kitchen with dishes and a silver sink. <end>',
#               '<start> A kitchen with a stove, sick, and dishes <end>'],
#              'D://Panoptic_2017/train2017/000000126657.jpg': ['<start> Several motorcycles riding down the road in formation. <end>',
#               '<start> A group of motorcycle riders driving past buildings. <end>',
#               '<start> A group of people are riding motorcycles on a road through a town.  <end>',
#               '<start> A group of motorcyclists are driving down the city street. <end>',
#               '<start> A group of motorcycles drive down a city street. <end>'],
#              'D://Panoptic_2017/train2017/000000285421.jpg': ['<start> A black cat is inside a white toilet. <end>',
#               '<start> A black cat drinking water from a toilet <end>',
#               '<start> A cat drinking water from a toilet in a bathroom. <end>',
#               '<start> A cat puts her head inside of a toilet.  <end>',
#               '<start> A cat is drinking water out of a toilet. <end>'],
#              'D://Panoptic_2017/train2017/000000071988.jpg': ['<start> A man in a wheelchair and another sitting on a bench that is overlooking the water. <end>',
#               '<start> Two people sitting on dock looking at the ocean. <end>',
#               '<start> Two older people sitting down in front of a beach. <end>',
#               '<start> An old couple at the beach during the day. <end>',
#               '<start> A person on a bench, and one on a wheelchair sitting by a seawall looking out toward the ocean <end>'],
#              'D://Panoptic_2017/train2017/000000193622.jpg': ['<start> A man sits with a traditionally decorated cow <end>',
#               '<start> A decorative man sits on the ground with a cow. <end>',
#               '<start> A man sits next to his horse in an alley in costume. <end>',
#               '<start> Guy and cow are sitting on the floor  <end>',
#               '<start> An Indian man in religious attire sitting with a decorated cow. <end>'],
#              'D://Panoptic_2017/train2017/000000459912.jpg': ['<start> Rows of motor bikes and helmets in a city <end>',
#               '<start> A lot of motorbikes line up down a busy street. <end>',
#               '<start> Large set of motorcycles all lined up down a street. <end>',
#               '<start> A large group of motorcycles lined up on the street. <end>',
#               '<start> A series of motorbikes parked in a row on a street <end>'],
#              'D://Panoptic_2017/train2017/000000548498.jpg': ['<start> A cute kitten is sitting in a dish on a table. <end>',
#               '<start> A small white cat on a large bowl. <end>',
#               '<start> A small kitten is sitting in a bowl.  <end>',
#               '<start> A cat is curled up in a bowl <end>',
#               '<start> A kitten is sitting in a bowl on a table. <end>'],
#              'D://Panoptic_2017/train2017/000000052087.jpg': ['<start> A man getting a drink from a water fountain that is a toilet. <end>',
#               '<start> A boy drinking water from a toilet water fountain. <end>',
#               '<start> A young man drinking from a water fountain in the shape of a toilet. <end>',
#               '<start> A young person has his face close to the toilet bowl. <end>',
#               '<start> A man taking a drink from a water fountain. <end>'],
#              'D://Panoptic_2017/train2017/000000119964.jpg': ['<start> A person holding a skateboard overlooks a dead field of crops. <end>',
#               '<start> A person sits on a patch of grass observing the scenery. <end>',
#               '<start> A person holding a skate board sitting in an empty open field. <end>',
#               '<start> A child with a skateboard sitting on the grass and looking at an empty field <end>',
#               '<start> A skateboarder sitting on the edge of an open field. <end>'],
#              'D://Panoptic_2017/train2017/000000230610.jpg': ['<start> A bathroom with a sink and shower curtain with a map print. <end>',
#               '<start> A small and crowded bathroom with little furnishing  <end>',
#               '<start> A small bathroom with a shower curtain with the NYC Subway map on it.  <end>',
#               '<start> A bathroom with a map as a shower curtain.  <end>',
#               '<start> A bathroom with pedestal sink and mirror over it. <end>'],
#              'D://Panoptic_2017/train2017/000000226419.jpg': ['<start> A random plane in the sky flying alone <end>',
#               '<start> An airplane flying high in the blue sky.  <end>',
#               '<start> A silver color jet flying through the clear sky. <end>',
#               "<start> An airplane with the letters 'MT' on it, flying in the sky. <end>",
#               '<start> A very large plane is flying through the sky. <end>'],
#              'D://Panoptic_2017/train2017/000000218026.jpg': ['<start> A brown and black horse in the middle of the city eating grass. <end>',
#               '<start> Two horses eating grass near a parking lot.  <end>',
#               '<start> Two horses standing in a field across the stre.et from a building <end>',
#               '<start> Two mules eating grass in a parking lot in front of a hotel.  <end>',
#               '<start> Two horses eat grass next to a group of parked cars. <end>'],
#              'D://Panoptic_2017/train2017/000000352538.jpg': ['<start> A brown purse is sitting on a green bench. <end>',
#               '<start> a brown purse abandoned on a green bench. <end>',
#               "<start> A woman's purse sitting on a park bench. <end>",
#               "<start> A leather purse laying on it's side on a green metal bench. <end>",
#               '<start> A purse sits alone on a park bench. <end>'],
#              'D://Panoptic_2017/train2017/000000202913.jpg': ['<start> Half of a white cake with coconuts on top. <end>',
#               '<start> The coconut cake on a red plate is half gone. <end>',
#               '<start> A half eaten dessert cake sitting on a cake plate. <end>',
#               '<start> A half eaten cake with coconut shavings and creme filling. <end>',
#               '<start> Half of a cake sits on a plate. <end>'],
#              'D://Panoptic_2017/train2017/000000202658.jpg': ['<start> An old toilet with a hello kitty cover top.  <end>',
#               '<start> A toilet with a Hello Kitty symbol on it. <end>',
#               '<start> A toilette with a pink hello kitty toilette seat cover. <end>',
#               '<start> A toilet with a Hello Kitty seat sitting in a room. <end>',
#               '<start> A broken toilet bowl with  a Hello Kitty toilet seat cover. <end>'],
#              'D://Panoptic_2017/train2017/000000079472.jpg': ['<start> Office space with office equipment on desk top. <end>',
#               '<start> A hope office setup of computers and printers. <end>',
#               '<start> a home office with laptop, printer, scanner, and extra monitor <end>',
#               '<start> The computer desk in the corner is by a window. <end>',
#               '<start> A laptop, monitor, printer and tablet on a desk. <end>'],
#              'D://Panoptic_2017/train2017/000000346071.jpg': ["<start> Two husky's hanging out of the car windows. <end>",
#               '<start> Dogs stick their heads out of car windows <end>',
#               '<start> Two husky dogs ride in a car with their heads hanging out windows. <end>',
#               '<start> Two happy dogs have their head out the car window. <end>',
#               '<start> Some dogs stick their heads out the car window. <end>'],
#              'D://Panoptic_2017/train2017/000000006672.jpg': ['<start> The back door with a window in the kitchen. <end>',
#               '<start> The kitchen has a white door with a window. <end>',
#               '<start> A kitchen door next to a kitchen sing and counter top. <end>',
#               '<start> A sink next to a large white door  <end>',
#               '<start> A door for exiting and entering the house in the kitchen. <end>'],
#              'D://Panoptic_2017/train2017/000000419074.jpg': ['<start> Jet liner flying off into the distance on an overcast day <end>',
#               '<start> An airplane flying away in a cloudy sky. <end>',
#               '<start> A plane that is flying in a clear blue sky. <end>',
#               '<start> An airplane flying away in the cloudy sky. <end>',
#               '<start> Four engine plane flying in lightly overcast sky. <end>'],
#              'D://Panoptic_2017/train2017/000000382406.jpg': ['<start> A woman is walking a dog in the city. <end>',
#               '<start> A woman and her dog walking down a sidewalk next to a fence with some flowers.  <end>',
#               '<start> A woman walking her dog on the sidewalk. <end>',
#               '<start> A woman walks her dog along a city street. <end>',
#               '<start> A woman walks her dog on a city sidewalk. <end>'],
#              'D://Panoptic_2017/train2017/000000175948.jpg': ['<start> A tiny bathroom with only a toilet and a shelf. <end>',
#               '<start> Small bathroom with a toilet and a sink. <end>',
#               '<start> A narrow bathroom has a white door on its side <end>',
#               '<start> Rather narrow bath room that appears to be being remodeled. <end>',
#               '<start> Unfinished bathroom with broken toilet next to a bookshelf. <end>'],
#              'D://Panoptic_2017/train2017/000000573223.jpg': ['<start> A little girl in a public bathroom for kids. <end>',
#               '<start> A girl standing next to a toilet in a bathroom. <end>',
#               '<start> Little girl in blue dress standing in a bathroom.  <end>',
#               '<start> An adorable little girl in a blue dress stands in a restroom. <end>',
#               '<start> A little girl in a blue dress stands in a bathroom. <end>'],
#              'D://Panoptic_2017/train2017/000000402514.jpg': ['<start> A picture of a man playing a violin in a kitchen. <end>',
#               '<start> A man is playing violin in his kitchen <end>',
#               '<start> A man is playing a fiddle in his kitchen. <end>',
#               '<start> A man plays the violin in a home. <end>',
#               '<start> An old man playing violin in a kitchen. <end>'],
#              'D://Panoptic_2017/train2017/000000407286.jpg': ["<start> A trio of dogs sitting in their owner's lap in a red convertible. <end>",
#               "<start> Three little dogs looking out a car window while sitting on a woman's lap.  <end>",
#               '<start> A woman driver has three dogs in the seat with her. <end>',
#               '<start> A woman and her three dogs in a car. <end>',
#               "<start> Three dogs on the lap of a woman in the driver's seat of a convertible. <end>"],
#              'D://Panoptic_2017/train2017/000000082673.jpg': ['<start> A small car is parked in front of a scooter <end>',
#               '<start> A scooter is parked behind a red car. <end>',
#               '<start> A small car parked in by a vespa. <end>',
#               '<start> A bus rides by a small car parked in front of a motor scooter <end>',
#               '<start> A small car sits parked in front of a scooter.  <end>'],
#              'D://Panoptic_2017/train2017/000000141172.jpg': ['<start> A door with a sticker of a cat door on it <end>',
#               "<start> A blue door with a painting of a cat's rear end entering thru a cat door. <end>",
#               '<start> A blue door with a picture of a cat door with cats backside hanging out on it. <end>',
#               '<start> A picture of a cat door is on the bottom corner of a blue door. <end>',
#               '<start> A painting on a door of a cat going through a cat door. <end>'],
#              'D://Panoptic_2017/train2017/000000104326.jpg': ['<start> A pinewood and green modern themed kitchen area. <end>',
#               '<start> A kitchen and dining room area with a large window. <end>',
#               '<start> A green kitchen with wooden counters and bright lights.  <end>',
#               '<start> A bright room with green walls and cabinets. <end>',
#               '<start> An empty kitchen area painted green with bulbous lights. <end>'],
#              'D://Panoptic_2017/train2017/000000581177.jpg': ['<start> A kitchen is shown with wooden cabinets and a wooden celling. <end>',
#               '<start> A recently remodeled kitchen with marble and wooden furnishings. <end>',
#               '<start> Well kept kitchen with marble counter tops and stainless steel fridge <end>',
#               '<start> A beautiful new kitchen with natural wood cabinets. <end>',
#               '<start> A neat, wood filled kitchen is photographed as if for a real estate ad. <end>'],
#              'D://Panoptic_2017/train2017/000000267802.jpg': ['<start> A group of people riding mopeds in a busy street.  <end>',
#               '<start> People riding bikes and cars down the street.  <end>',
#               '<start> Motorists and bicyclists in a busy city square. <end>',
#               '<start> A crowded city street filled with traffic and bicycles. <end>',
#               '<start> An Asian intersection is full of mopeds and motorcycles. <end>'],
#              'D://Panoptic_2017/train2017/000000208408.jpg': ['<start> A person walking in the rain on the sidewalk.  <end>',
#               '<start> A person walking through the rain with an umbrella. <end>',
#               '<start> A person walking in the rain while holding an umbrella. <end>',
#               '<start> A man walks down the strip as it rains. <end>',
#               '<start> A European street scene with a person and vehicles. <end>'],
#              'D://Panoptic_2017/train2017/000000560591.jpg': ['<start> a modern flush toilet in a bathroom with tile.  <end>',
#               '<start> A toilet and trashcan in a white bathroom. <end>',
#               '<start> A white toilet sits on a tile floor. <end>',
#               '<start> A toilet in a bathroom that is next to a trash can <end>',
#               '<start> White toilet by built-in shelves in a tiled bathroom. <end>'],
#              'D://Panoptic_2017/train2017/000000507362.jpg': ['<start> Fog is in the air at an intersection with several traffic lights. <end>',
#               '<start> An intersection during a cold and foggy night. <end>',
#               '<start> Empty fog covered streets in the night amongst traffic lights. <end>',
#               '<start> City street at night with several stop lights. <end>',
#               '<start> It is a foggy night by a traffic light. <end>'],
#              'D://Panoptic_2017/train2017/000000057429.jpg': ['<start> An airplane with its landing wheels out landing.  <end>',
#               '<start> A plane that is taking off at an airport <end>',
#               '<start> A man takes a picture of an airplane taking off. <end>',
#               '<start> A large jet takes off from an airport runway. <end>',
#               '<start> The airplane is taking off on the runway at the airport. <end>'],
#              'D://Panoptic_2017/train2017/000000153184.jpg': ['<start> Little birds sitting on the shoulder of a giraffe.  <end>',
#               "<start> The top of a giraffe's head has birds on it. <end>",
#               '<start> Three birds sit on the back of a giraffe.  <end>',
#               '<start> A giraffe with 3 birds on his fur. <end>',
#               '<start> A flock of birds sits on top of a large giraffe. <end>'],
#              'D://Panoptic_2017/train2017/000000571970.jpg': ['<start> a man with a bike at a marina <end>',
#               '<start> A man stands next to his bike at the marina. <end>',
#               '<start> an old man standing next to a bike and a chain fence. <end>',
#               '<start> A man holding some break standing by a bicycle. <end>',
#               '<start> A man who is standing next to his bicycle. <end>'],
#              'D://Panoptic_2017/train2017/000000133680.jpg': ['<start> A man is sitting on a bench next to a bike. <end>',
#               '<start> A man is sitting on a bench next to a bicycle. <end>',
#               '<start> A man sits on a street bench by a bike.  <end>',
#               '<start> Black man sitting on a bench behind a personal bicycle.  <end>',
#               '<start> A man is sitting in a busy area with his bike. <end>'],
#              'D://Panoptic_2017/train2017/000000139011.jpg': ['<start> People are waiting for the bus near a bus stop. <end>',
#               '<start> A crowd of people are waiting to get on a red bus. <end>',
#               '<start> A crowd of people get ready to board a bus in the city. <end>',
#               '<start> Large group of people waiting for a train. <end>',
#               '<start> People are waiting in a city area to board a bus. <end>'],
#              'D://Panoptic_2017/train2017/000000505386.jpg': ['<start> four urinals in a public restroom with a window <end>',
#               '<start> A bathroom with four urinals on the wall. <end>',
#               '<start> An old bathroom with a row of urinals. <end>',
#               '<start> A row of urinals in with an open window above them. <end>',
#               '<start> A row of urinals stand beneath a open window. <end>'],
#              'D://Panoptic_2017/train2017/000000107990.jpg': ['<start> A small child climbs atop a large motorcycle <end>',
#               '<start> A young boy riding a motorcycle next to a silver car. <end>',
#               '<start> A little baby is sitting on a huge motorcycle. <end>',
#               '<start> A little boy sitting alone on a motorcycle. <end>',
#               '<start> A toddler sitting on a motorcycle in a parking lot. <end>'],
#              'D://Panoptic_2017/train2017/000000527510.jpg': ['<start> A large U.S Air Force plain sits on an asphalt ramp. <end>',
#               '<start> A large propeller airplane sitting on a tarmac. <end>',
#               '<start> A large military plane parked in the landing area. <end>',
#               '<start> A U.S. Air Force plane sits on display. <end>',
#               '<start> A picture of a plane in a runway. <end>'],
#              'D://Panoptic_2017/train2017/000000005247.jpg': ['<start> A black and white photo of an older man skiing. <end>',
#               '<start> Two people on the snow for cross country skiing. <end>',
#               '<start> The old man cross country skis through the forest. <end>',
#               '<start> A younger man and an older man skiing in the forest. <end>',
#               '<start> Two people on skis going through the woods.\n <end>'],
#              'D://Panoptic_2017/train2017/000000107960.jpg': ['<start> Riding a motorcycle down a street that has no one else on it. <end>',
#               "<start> The view from a motorcyclist's point of view, looking down a street. <end>",
#               '<start> A man rides a motorcycle down an empty street next to houses. <end>',
#               '<start> The view of the street from the perspective of the rider of a motorcycle <end>',
#               '<start> A motorcycle moves forward down an empty street. <end>'],
#              'D://Panoptic_2017/train2017/000000410627.jpg': ['<start> The young man is stirring his pot of food with a wooden spoon. <end>',
#               '<start> A man enjoys cooking food in a pan <end>',
#               '<start> A smiling man is cooking in his kitchen. <end>',
#               '<start> A man smiles as he stirs his food in the pot. <end>',
#               '<start> A boy smiles while holding a pot and spoon. <end>'],
#              'D://Panoptic_2017/train2017/000000232223.jpg': ['<start> A fighter jet is flying at a fast speed. <end>',
#               '<start> A fighter jet soars up into a blue sky. <end>',
#               '<start> An old military jet fighter climbing in altitude. <end>',
#               '<start> A fighter jet flying through the sky with smoke coming off of it. <end>',
#               '<start> A figher jet creating condensation flying through the blue sky. <end>'],
#              'D://Panoptic_2017/train2017/000000022793.jpg': ['<start> A public bathroom with a bunch of urinals. <end>',
#               '<start> A picture of a woman hangs on the wall above the urinals. <end>',
#               "<start> A men's restroom with a poster of a woman over the urinals. <end>",
#               '<start> White tiled bathroom with line of tiles and Asian female poster on the wall <end>',
#               '<start> A mens restroom is lined up with urinals. <end>'],
#              'D://Panoptic_2017/train2017/000000436456.jpg': ['<start> The airplane is on the runway with two young men standing by. <end>',
#               '<start> Two men walking the tarmac of an airport. <end>',
#               '<start> Two men at on an airport tarmac. \n <end>',
#               '<start> Two young men walking down a runway toward an airplane. <end>',
#               '<start> Young men are preparing to board a small passenger plane. <end>'],
#              'D://Panoptic_2017/train2017/000000368402.jpg': ['<start> The woman in the kitchen is holding a huge pan. <end>',
#               '<start> A chef carrying a large pan inside of a kitchen. <end>',
#               '<start> A woman is holding a large pan in a kitchen.  <end>',
#               '<start> A woman cooking in a kitchen with granite counters. <end>',
#               '<start> A woman cooking in her kitchen with a black pan. <end>'],
#              'D://Panoptic_2017/train2017/000000135161.jpg': ['<start> A toilet sits next to a window and in front of a shower. <end>',
#               '<start> A bathroom with only a toilet and tub with the wall covered in plastic <end>',
#               '<start> A photograph of a bathroom undergoing some renovations. <end>',
#               '<start> A bathroom being renovated featuring a toilette and shower. <end>',
#               '<start> A bathroom in the middle of a reconstruction phase. <end>'],
#              'D://Panoptic_2017/train2017/000000178761.jpg': ['<start> A dog and a goat with their noses touching at fence. <end>',
#               '<start> A dog greets a sheep that is in a sheep pen. <end>',
#               '<start> Two animals get close through a fence.  <end>',
#               '<start> A sheep and a dog touching noses through a fence. <end>',
#               '<start> a couple of animals that are beside a fence <end>'],
#              'D://Panoptic_2017/train2017/000000491000.jpg': ['<start> Pedestrians walking down a sidewalk next to a small street. <end>',
#               '<start> People walking on a city street with light traffic. <end>',
#               '<start> A city street with people walking and vehicles on the road. <end>',
#               '<start> A scenic photograph of an urban street with people and traffic. <end>',
#               '<start> Pedestrians are strolling along a city sidestreet in a touristy neighborhood. <end>'],
#              'D://Panoptic_2017/train2017/000000538092.jpg': ['<start> A man standing in a kitchen while closing a cupboard door. <end>',
#               '<start> A man standing in kitchen surrounded by items. <end>',
#               '<start> A kitchen area with a cooler and container stacked on the floor and a man getting an item out of a cabinet. <end>',
#               '<start> A man holding a cabinet in a kitchen. <end>',
#               '<start> a man stocking up his kitchen with groceries <end>'],
#              'D://Panoptic_2017/train2017/000000205577.jpg': ['<start> A photograph of a kitchen inside a house. <end>',
#               '<start> This is an apartment kitchen with white cabinets and appliances. <end>',
#               '<start> A shot of a kitchen with a microwave, sink, dishwasher, and refrigerator.  <end>',
#               '<start> A kitchen with a refrigerator, microwave, dishwasher and sink. <end>',
#               '<start> A kitchen with a sink, dishwasher, microwave and refrigerator. <end>'],
#              'D://Panoptic_2017/train2017/000000508672.jpg': ['<start> a bike leaning on a metal fence next to some flowing water.  <end>',
#               '<start> A bicycle parked next to a flooded river <end>',
#               '<start> A bicycle chained to a rail near a flooded area. <end>',
#               '<start> A bicycle leans against a fence near some flood waters. <end>',
#               '<start> A bicycle parked on a rail next to some flooding water. <end>'],
#              'D://Panoptic_2017/train2017/000000334015.jpg': ['<start> a small toilet stall with a toilet brush and 3 rolls of toilet paper  <end>',
#               '<start> A clean, European toilet with toilet paper and cleaning brush. <end>',
#               '<start> A public toilet stall with toilet paper and a cleaning brush. <end>',
#               '<start> An empty, clean toilet stall with a stack of toilet paper. <end>',
#               '<start> There is a white toilet in a very narrow bathroom. <end>'],
#              'D://Panoptic_2017/train2017/000000027842.jpg': ['<start> A dual sink vanity with mirrors above the sinks. <end>',
#               '<start> A long marble like bath room vanity with a stool, two sink basins with mirrors and lights over them <end>',
#               '<start> A double sink with mirrors and a stool underneath it. <end>',
#               '<start> There are two sinks in the clean bathroom. <end>',
#               '<start> A bathroom with his and her mirrors and sinks. <end>'],
#              'D://Panoptic_2017/train2017/000000358606.jpg': ['<start> A fireplace with a fire built in it. <end>',
#               '<start> A living room containing a modern fireplace and miscellaneous items  <end>',
#               '<start> A lit fire place in a living room next to a TV. <end>',
#               '<start> A brick fireplace with fire adorned with knick-knacks. <end>',
#               '<start> A living room, with fireplace, television, and throw rug. <end>'],
#              'D://Panoptic_2017/train2017/000000567730.jpg': ['<start> The sign of a restaurant in the outside of the store. <end>',
#               '<start> A sign on a building advertising an Italian restaurant. <end>',
#               '<start> A sign for an Italian restaurant hangs outside a building. <end>',
#               '<start> Italian Reaffaello restaurant sign at front of building. <end>',
#               '<start> A sign outside of a restaurant for Italian food.  <end>'],
#              'D://Panoptic_2017/train2017/000000061259.jpg': ['<start> an airport with one plane flying away and the other sitting on the runway <end>',
#               '<start> jumbo jet sits on the tarmac while another takes off <end>',
#               '<start> A Virgin Australia airline on the tarmac.  <end>',
#               '<start> Virgin sponsored airplane parked with a plane leaving in the background. <end>',
#               '<start> One airplane is taking off from an airport while others are parked. <end>'],
#              'D://Panoptic_2017/train2017/000000554037.jpg': ['<start> a counter with vegetables, knife and cutting board on it.  <end>',
#               '<start> asparragus, lemons and a bowl of rice on a counter top <end>',
#               '<start> The preparation of salmon, asparagus and lemons.  <end>',
#               '<start> Cooking table with assorted fish and lemons with asparagus.  <end>',
#               '<start> A kitchen counter with cutting board, knife and food. <end>'],
#              'D://Panoptic_2017/train2017/000000005394.jpg': ['<start> A boat that looks like a car moves through the water.  <end>',
#               '<start> A car modified to drive in the water on a lake. <end>',
#               '<start> A car modified to be a boat on the water. <end>',
#               '<start> A picture of a boat that looks like a car in the water. <end>',
#               '<start> a car that has been converted into a boat floating on water <end>'],
#              'D://Panoptic_2017/train2017/000000455384.jpg': ['<start> A delivery truck with an advertisement for Entourage. <end>',
#               '<start> A large van features an ad for a television show. <end>',
#               '<start> A truck with an ad for a television show painted on its side <end>',
#               "<start> A large delivery truck with an advertisement painted on it's side. <end>",
#               '<start> An entourage decorated van is parked on the side of the road.   <end>'],
#              'D://Panoptic_2017/train2017/000000249352.jpg': ['<start> A black and white toilet with a plunger. <end>',
#               '<start> A toilet has a rug, and a plunger next to it. <end>',
#               '<start> A small stall with large tiles, a toilet and two plungers <end>',
#               '<start> A small restroom with a single toilet and wooden toilet seat. <end>',
#               '<start> A toilet, plunger and rug in a tiled bathroom stall. <end>'],
#              'D://Panoptic_2017/train2017/000000348306.jpg': ['<start> A bike leaning against a sign in Scotland. <end>',
#               '<start> A bike in front of a scenic welcome sign.  <end>',
#               '<start> a welcome to Scotland sign with a bicycle leaning on it <end>',
#               '<start> Bicycle leaning up against a welcome to Scotland sign. <end>',
#               '<start> A sign for a village in Scotland with a bicycle in front of it. <end>'],
#              'D://Panoptic_2017/train2017/000000475593.jpg': ['<start> Women father around a desk and machinery in a factory. <end>',
#               '<start> A photo set of two women at work <end>',
#               '<start> Women working in a commercial bakery or kitchen. <end>',
#               '<start> Two old photos with women in a kitchen. <end>',
#               '<start> two women in white work at an industrial kitchen counter and stove <end>'],
#              'D://Panoptic_2017/train2017/000000145523.jpg': ['<start> A few items sit on top of a toilet in a bathroom stall. <end>',
#               '<start> A dirty toilet in a small bathroom.with items on top. <end>',
#               '<start> A toilet seat is left open inside of a bathroom. <end>',
#               '<start> A dirty toilet in a small cramped space. <end>',
#               '<start> A photo of a toilet with items on the tank. <end>'],
#              'D://Panoptic_2017/train2017/000000143370.jpg': ['<start> A bathroom with a poster of an ugly face above the toilette. <end>',
#               '<start> A bathroom with a white toilet and sink. <end>',
#               '<start> Large bathroom with light flowing in the window. <end>',
#               '<start> A small bathroom with a toilet by the window and a pedestal sink with a mirrored medicine cabinet over it <end>',
#               '<start> A bathroom with a toilet and a sink. <end>'],
#              'D://Panoptic_2017/train2017/000000279806.jpg': ['<start> A dirt bike rider doing a stunt jump in the air <end>',
#               '<start> A man riding a dirt bike becomes airborne. <end>',
#               '<start> A motorcyclist is in mid air hanging on to the handlebars. <end>',
#               '<start> A person performs a stunt jump on a motorcycle. <end>',
#               '<start> Daring guy does tricks mid air on motorcycle <end>'],
#              'D://Panoptic_2017/train2017/000000059171.jpg': ['<start> A couple of birds fly through a blue cloudy sky. <end>',
#               '<start> Group of three people sailing kites up in the sky.  <end>',
#               '<start> A beautiful blue and pink sky overlooking the beach. <end>',
#               '<start> Group of people are flying kites on the beach. <end>',
#               '<start> This is a gorgeous sunset at a beach with a parasailor in the distance. <end>'],
#              'D://Panoptic_2017/train2017/000000369826.jpg': ['<start> A picture advertising Arizona tourism in an airport <end>',
#               '<start> A television that is sitting next to signs <end>',
#               '<start> A television is shown in the middle of a baggage claim area. <end>',
#               '<start> An airport terminal has a big screen displaying an ad for Arizona. <end>',
#               '<start> A flat screen TV with a picture of a person jumping on it. <end>'],
#              'D://Panoptic_2017/train2017/000000400552.jpg': ['<start> A variety of pots are stored in a nook by a fireplace. <end>',
#               '<start> A room contains baskets and has a fireplace.  <end>',
#               '<start> A room filled with clutter and a fireplace. <end>',
#               '<start> A small living room with a fireplace and work baskets.\n <end>',
#               '<start> A room with a fir place and several baskets and a bench in the background. <end>'],
#              'D://Panoptic_2017/train2017/000000238836.jpg': ['<start> A car is stopped at a red light <end>',
#               '<start> The car is at the intersection while the sun is setting. <end>',
#               '<start> A truck nears a stop light in rainy weather. <end>',
#               '<start> A car is at a red light in the rain. <end>',
#               '<start> An intersection with a red traffic light and a vehicle. <end>'],
#              'D://Panoptic_2017/train2017/000000264461.jpg': ['<start> A bathroom with a traditional toilet next to a floor toilet. <end>',
#               '<start> A squat toilet and a Western toilet are next to each other. <end>',
#               '<start> Mans bathroom with two visible fixtures, trash basket and plunger in sight. <end>',
#               '<start> A toilet stall, complete with two clean toilets. <end>',
#               '<start> A bathroom with an odd toilette next to a normal toilette. <end>'],
#              'D://Panoptic_2017/train2017/000000342387.jpg': ['<start> A group of people preparing food in a kitchen. <end>',
#               '<start> Group of people all sorting vegetables in a line. <end>',
#               '<start> Six different people in aprons and hats preparing vegetables <end>',
#               '<start> A group of people are in a line working on green vegetables. <end>',
#               '<start> A team of chefs work together to prepare a meal. <end>'],
#              'D://Panoptic_2017/train2017/000000488327.jpg': ['<start> Posted signs point the way through a parking garage. <end>',
#               '<start> Three traffic signs at the entrance of a parking garage.  <end>',
#               '<start> Three road signs posted in a parking garage. <end>',
#               '<start> This is a parking garage with several signs. <end>',
#               '<start>  directing signs in front of a parking garage <end>'],
#              'D://Panoptic_2017/train2017/000000540860.jpg': ['<start> A green car on display next to a busy street. <end>',
#               '<start> A sculpture of a green hot rod on a city sidewalk <end>',
#               '<start> A sculpture of a hot rod sitting on a sidewalk. <end>',
#               '<start> This is a city art piece of a small car. <end>',
#               '<start> A small green vehicle model is on display next to a busy city street. <end>'],
#              'D://Panoptic_2017/train2017/000000172851.jpg': ['<start> A large passenger jet taking off from an airport. <end>',
#               '<start> A plane that just took off flying from an airport. <end>',
#               '<start> The airplane has begun its ascent in the skies. <end>',
#               '<start> A plane is shown taking off from an airstrip. <end>',
#               '<start> An airplane is taking off at an airport. <end>'],
#              'D://Panoptic_2017/train2017/000000486194.jpg': ['<start> Young woman carrying an opened umbrella in a city neighborhood. <end>',
#               '<start> A woman walking while holding up a red umbrella  <end>',
#               '<start> A beautiful young lady walking in the rain while holding an umbrella. <end>',
#               '<start> A woman holding a red umbrella traveling down a sidewalk. <end>',
#               '<start> A young woman is carrying a red umbrella. <end>'],
#              'D://Panoptic_2017/train2017/000000236148.jpg': ["<start> An older man backing up a truck with a bicycle in it's flat bed. <end>",
#               '<start> A man looking out the back window of his truck. <end>',
#               '<start> A man sits in the drivers seat of a truck. <end>',
#               '<start> A man in a truck looks out his rear window. <end>',
#               '<start> A man in a truck looking behind him. <end>'],
#              'D://Panoptic_2017/train2017/000000115930.jpg': ['<start> A group of men standing in front of a bar having a conversation. <end>',
#               '<start> Restaurant staff taking a break near the bar. <end>',
#               '<start> Several men having a conversation at a restaurant. <end>',
#               '<start> Three workers at a restaurant visiting with each other and customers. <end>',
#               '<start> Three chefs talking to each other at a bar. <end>'],
#              'D://Panoptic_2017/train2017/000000075663.jpg': ['<start> A children play area absent of any children. <end>',
#               '<start> A craft supply room with craft supplies and containers. <end>',
#               '<start> A work area room that is very very clean. <end>',
#               "<start> A little children's classroom with materials and toys.  <end>",
#               '<start> A counter top that has bins and a bucket of glue on it. <end>',
#               '<start> A toy kitchen with a small table phone hat and teddy bear, with assorted crafts on the counter. <end>'],
#              'D://Panoptic_2017/train2017/000000352794.jpg': ['<start> Fruit in a jar filled with liquid sitting on a wooden table. <end>',
#               '<start> Some yellow objects are floating in red liquid in a jar. <end>',
#               '<start> There is a jar filled with an unknown liquid and solid. <end>',
#               '<start> A jar of homemade sangria sitting on a table. <end>',
#               '<start> A jar filled with liquid sits on a wood surface. <end>'],
#              'D://Panoptic_2017/train2017/000000175954.jpg': ['<start> A work station in use inside an office. <end>',
#               '<start> A desk inside a library with a computer and several papers on it. <end>',
#               '<start> A workstation with a computer, notebook, and papers. <end>',
#               '<start> An office desk with a lot of paperwork and a turned on computer <end>',
#               '<start> The computer is turned on at the cluttered workstation. <end>'],
#              'D://Panoptic_2017/train2017/000000484751.jpg': ['<start> Three computer screens showing a panoramic beach scene. <end>',
#               '<start> Three computer screens at a desk show a panoramic view of the ocean. <end>',
#               '<start> A desk with multiple computer screens forming one large screen. <end>',
#               '<start> A computer desk with a triple monitor computer setup. <end>',
#               '<start>  There are three tvs with a keyboard in front of it <end>'],
#              'D://Panoptic_2017/train2017/000000457834.jpg': ['<start> Elephants are in a long line with people on top of them. <end>',
#               '<start> Several people riding on the back of elephants <end>',
#               '<start> A group of men riding elephants down a street surrounded by trees. <end>',
#               '<start> People riding on top of elephants that are walking in a line across a road.  <end>',
#               '<start> There is a parade of elephants walking across the road. <end>'],
#              'D://Panoptic_2017/train2017/000000412151.jpg': ['<start> A bicycle store shows two males leaning toward a bike. <end>',
#               '<start> A man adjust a bicycle in a bike shop with a child. <end>',
#               '<start> The bike shop employee is helping a customer.  <end>',
#               '<start> A man and a boy are talking about a bicycle in a store. <end>',
#               '<start> Two people in a shop looking at a bike. <end>'],
#              'D://Panoptic_2017/train2017/000000427091.jpg': ['<start> City traffic and pedestrians are headed in multiple directions on the street. <end>',
#               '<start> A city street busy with many cars driving as well as pedestrians <end>',
#               '<start> People in a city cross in front of traffic.  <end>',
#               '<start> Traffic in New York City during the day.  <end>',
#               '<start> Cars stopped on a busy street while pedestrians cross. <end>'],
#              'D://Panoptic_2017/train2017/000000032203.jpg': ['<start> There are some dirt bike riders taking a sharp turn <end>',
#               '<start> Dirt bikers racing around a corner on the track <end>',
#               '<start> Motor bike racers race each other around a track. <end>',
#               '<start> Dirt bike racers rounding a corner on a track with orange barriers <end>',
#               '<start> Three people on motorbikes racing around a track. <end>'],
#              'D://Panoptic_2017/train2017/000000525971.jpg': ['<start> A large group of motorcycle riders collect in a parking lot.  <end>',
#               '<start> A street full of motorcycles and their riders <end>',
#               '<start> Several bikers are lined up in a parking lot. <end>',
#               '<start> Motorcyclist meeting with one another before a ride. <end>',
#               '<start> There is no picture or image sorry sorry <end>'],
#              'D://Panoptic_2017/train2017/000000354572.jpg': ['<start> People sitting under an umbrella looking at the scenery. <end>',
#               '<start> A person with a colorful umbrella sits on a fountain. <end>',
#               '<start> A man with a colored umbrella sits on a monument. <end>',
#               '<start> A man sis on a public area while holding an umbrella. <end>',
#               '<start> This is a photo of two people sitting on the ledge of a piece of city artwork. <end>'],
#              'D://Panoptic_2017/train2017/000000185360.jpg': ['<start> A cow standing next to a damaged car on a dirty lot. <end>',
#               '<start> A broken down car being investigated by a cow. <end>',
#               '<start> A cow stands in the mud next to a car. <end>',
#               '<start> An abandoned car and a cow on a field. <end>',
#               '<start> A cow standing by a damaged car in a field. <end>'],
#              'D://Panoptic_2017/train2017/000000321064.jpg': ['<start> A small wooden table covered with delicious vegetables.  <end>',
#               '<start> A dining table with a bowl of garlic cloves. <end>',
#               '<start> A kitchen table with a juicer and vegetable on it. <end>',
#               '<start> A kitchen table with vegetables and food processor. <end>',
#               '<start> A food processor sit on a small table in a kitchen next to fresh vegetables and a colander of mushrooms. <end>'],
#              'D://Panoptic_2017/train2017/000000263664.jpg': ['<start> A couple on a motorcycle in front of a bus and a metermaid car <end>',
#               '<start> A busy city street with a bus, taxi, and motorcycle. <end>',
#               '<start> A bus, riksha, and two men on a scooter all on the same road.  <end>',
#               '<start> Buses and motorcycles driving down a city street. <end>',
#               '<start> Two people riding on a moped with a bus in the next lane. <end>'],
#              'D://Panoptic_2017/train2017/000000468508.jpg': ['<start> A red motorcycle parked on a sidewalk near multi-story buildings. <end>',
#               '<start> A motorcycle that is parked on the side of the road. <end>',
#               '<start> A motorcycle is parked on a cobblestone road <end>',
#               '<start> A red motorcycle parked on a brick street. <end>',
#               '<start> Motorcycle parked along brick paved street with shops. <end>'],
# ...
#               '<start> A police car sitting in front of a fire hydrant. <end>'],
#              'D://Panoptic_2017/train2017/000000000164.jpg': ['<start> A small kitchen with low a ceiling  <end>',
#               '<start> A small kichen area with a sunlight and and angled ceiling. <end>',
#               '<start> an image of a kitchen loft style setting <end>',
#               '<start> a small kitchen with a lot of filled up shelves  <end>',
#               '<start> A kitchen with a slanted ceiling and skylight. <end>'],
#              'D://Panoptic_2017/train2017/000000267861.jpg': ['<start> A red motorcycle with a back seat parked on the side of a road. <end>',
#               '<start> A tricycle is shown on the side of the road. <end>',
#               '<start> There is a nice tricycle motrocycle parked on a sidewalk <end>',
#               '<start> A red motorcycle with three wheels and two seats. <end>',
#               '<start> a close up of a three wheeled motor cycle <end>'],
#              'D://Panoptic_2017/train2017/000000469638.jpg': ['<start> A bathroom that is very clean and white. <end>',
#               '<start> A white bathroom looking at the cabinet sink <end>',
#               '<start> a white bathroom with a black and white shower curtain <end>',
#               '<start> A bathroom sink under a window.next to a shower. <end>',
#               '<start> The small bathroom is very clean and empty. <end>'],
#              'D://Panoptic_2017/train2017/000000246265.jpg': ['<start> Many motorcycles are parked around a crowd of people. <end>',
#               '<start> A bunch of motorcycles parked outside a factory building <end>',
#               '<start> A group of bikers sitting in front of a mechanic shop. <end>',
#               '<start> A garage has many riders and motorcycles outside. <end>',
#               '<start> A group of motorcycles are parked outside of the garage. <end>'],
#              'D://Panoptic_2017/train2017/000000010114.jpg': ['<start> A picture of a very nice kitchen that is white. <end>',
#               '<start> A small residential kitchen with white cabinets and appliances. <end>',
#               '<start> A kitchen filled with a white stove top oven. <end>',
#               '<start> A kitchen scene complete with a fridge and an oven. <end>',
#               '<start> A dated kitchen reveals a wall hung faucet under a closed off window. <end>'],
#              'D://Panoptic_2017/train2017/000000371683.jpg': ['<start> A bunch of bananas hanging from a green tree. <end>',
#               '<start> A bunch of bananas and leaves are pictured up close. <end>',
#               '<start> A large bunch of bananas hanging from a tree. <end>',
#               '<start> A banana tree with a bunch of bananas hanging from it <end>',
#               '<start> an image of a plantation of bananas on vine <end>'],
#              'D://Panoptic_2017/train2017/000000392650.jpg': ['<start> A large Delta passenger jet flying through a blue sky. <end>',
#               '<start> An airplane soaring into a cloudless blue sky. <end>',
#               '<start> Blue sky with delta jumbo jet taking off <end>',
#               '<start> A commercial airplane is ascending in the sky. <end>',
#               '<start> A delta flight lifting taking off into the sky. <end>'],
#              'D://Panoptic_2017/train2017/000000579602.jpg': ['<start> Three kites in the air with many umbrellas on a beach <end>',
#               '<start> an image of a kite flying high in the air <end>',
#               '<start> Three colorful kites fly high above a beach with a radio controlled model plane. <end>',
#               '<start> A crowded beach with giant kites flying over head. <end>',
#               '<start> Colorful kites flying above a beach scene of sand and umbrellas. <end>'],
#              'D://Panoptic_2017/train2017/000000023623.jpg': ['<start> His and her bathroom sinks underneath a large mirror. <end>',
#               '<start> A bathroom vanity with two sinks and a large mirror over it. <end>',
#               '<start> Two sinks are shown on a bathroom counter. <end>',
#               '<start> a bathroom with two sinks at the counter with a large mirror on top <end>',
#               '<start> A BATHROOM WITH A SINK AND A MIRROR  <end>'],
#              'D://Panoptic_2017/train2017/000000180787.jpg': ['<start> A picture of some people that are cooking some food. <end>',
#               '<start> some people wearing black and cooking food in a big kitchen <end>',
#               '<start> A kitchen scene with several people preparing food. <end>',
#               '<start> The kitchen of a large restaurant showing a carving station <end>',
#               '<start> A couple of chefs preparing food in a kitchen. <end>'],
#              'D://Panoptic_2017/train2017/000000467475.jpg': ['<start> A formation of birds in a sky at sunset. <end>',
#               '<start> A airplane followed by birds flying in "v-formation." <end>',
#               '<start> AIRPLANE IN THE SKY WITH A FOLLOWING OF GEESE BEHIND <end>',
#               '<start> A flock of birds below an airplane in the sunset <end>',
#               '<start> A plane flying in the sky, as birds fly behind it. <end>'],
#              'D://Panoptic_2017/train2017/000000095772.jpg': ['<start> A pile of rusted metal junk laying in the weeds. <end>',
#               '<start> A rusty apparatus is laying in a green thicket. <end>',
#               '<start> old rusted metal on the floor with many plants and trees <end>',
#               '<start> A pile of scrap metal sitting on the floor of a forest. <end>',
#               '<start> The rusty remains of a metal device in green weeds <end>'],
#              'D://Panoptic_2017/train2017/000000453020.jpg': ['<start> A public restroom with several urinals and stalls. <end>',
#               '<start> a bathroom with multiple toilet stalls and urinals  <end>',
#               '<start> A clean public bathroom with black and white tile. <end>',
#               '<start> A restroom filled with urinals and toilet stalls. <end>',
#               '<start> A public bathroom with four toilet stalls and four urinals on the wall. <end>'],
#              'D://Panoptic_2017/train2017/000000255482.jpg': ['<start> A blue turboprop airplane races across the blue sky. <end>',
#               '<start> an air plane flying thru the air with a sky background <end>',
#               '<start> View of a plane flying through a very blue sky <end>',
#               '<start> A large airplane with four propellers flying through a blue sky <end>',
#               '<start> A blue airplane in a blue, cloudless sky <end>'],
#              'D://Panoptic_2017/train2017/000000188651.jpg': ['<start> The picture of a cat under a car. <end>',
#               '<start> A white and broncat is sitting under a car  <end>',
#               '<start> A cat lays on the ground underneath a vehicle. <end>',
#               '<start> a cat chillin under a car, asking to get run over <end>',
#               '<start> A white cat is sitting under a car. <end>'],
#              'D://Panoptic_2017/train2017/000000370090.jpg': ['<start> A blue toilet bowl in a bathroom that says rabies <end>',
#               '<start> This is a blue toilet that has white graffiti on it <end>',
#               '<start> A blue toilet with the word rabies written on the underside of the toilet seat. <end>',
#               '<start> an image of a blue toilet with the word babies <end>',
#               '<start> Blue toilet in a small restroom with words written on it.  <end>'],
#              'D://Panoptic_2017/train2017/000000327514.jpg': ['<start> A man standing in a kitchen ironing his clothes while cooking food. <end>',
#               '<start> A person in the kitchen ironing and checking the contents of a pot. <end>',
#               '<start> Man ironing while opening a pot on top of a stove.  <end>',
#               '<start> A person that is ironing some clothes and getting some food. <end>',
#               '<start> A young man checks on his cooking while he irons. <end>'],
#              'D://Panoptic_2017/train2017/000000428234.jpg': ['<start> A plant is growing on the window sill in the bathroom. <end>',
#               '<start> a bathroom with a toilet a window and a shelf <end>',
#               '<start> A bathroom with the focus on the toilet. <end>',
#               '<start> A white bathroom area with a plant and yellow bottle. <end>',
#               '<start> A bathroom toilet, scrub brush holder and a spider plant on the windowsill <end>'],
#              'D://Panoptic_2017/train2017/000000213932.jpg': ['<start> A picture of a motorcycle on the street. <end>',
#               '<start> A motorcycle sits on a street near shops. <end>',
#               '<start> A black motorcycle parked on a city street. <end>',
#               '<start> A black motorcycle parked on a street by a store. <end>',
#               '<start> A motorcycle parked on the side of the road. <end>'],
#              'D://Panoptic_2017/train2017/000000462026.jpg': ['<start> Several beautiful vintage racing motorcycles on public display. <end>',
#               '<start> there are many different dirt bikes on display <end>',
#               '<start> Two small bikes in front of signs describing them. <end>',
#               '<start> a motored bike display for a minarelli bike <end>',
#               '<start> Several dirt bikes are standing in a row. <end>'],
#              'D://Panoptic_2017/train2017/000000401783.jpg': ['<start> A view of the mountains is shown from an airplane window. <end>',
#               '<start> You can see a long way in the plane. <end>',
#               '<start> WING OF AN AIRPLANE SHOWN FLYING OVER THE MOUNTAINS <end>',
#               '<start> The view from an airplane window over mountains <end>',
#               '<start> A picture of a plane that is in the air around the mountains. <end>'],
#              'D://Panoptic_2017/train2017/000000168512.jpg': ['<start> A turkey or chicken cooks inside a kitchen oven. <end>',
#               '<start> A lit oven displays a turkey and a pan of vegetables roasting side by side. <end>',
#               '<start> A turkey and other foods are cooking in an oven. <end>',
#               '<start> A turkey and vegetables cooking in an oven with a glass window on the door. <end>',
#               '<start> Stainless steel oven with pan of vegetables and a turkey in the oven. <end>'],
#              'D://Panoptic_2017/train2017/000000431236.jpg': ['<start> A kitchen with a washer and a stove top oven. <end>',
#               '<start> A room is shown with a washer and oven. <end>',
#               '<start> A kitchen with a white stove and washing machine <end>',
#               '<start> An oven, and clothes washer are in a small kitchen. <end>',
#               '<start> a kitchen with a stove a dih washer and a mcirowave <end>'],
#              'D://Panoptic_2017/train2017/000000172911.jpg': ['<start> A car seat covered in a piece of cake and frosting. <end>',
#               '<start> Junk in green and other colors sit on a car seat. <end>',
#               '<start> A bunch of garbage is on a car seat. <end>',
#               '<start> Broken glass is shown in the seat of a car. <end>',
#               '<start> A phone lies amid shattered glass on a car seat. <end>'],
#              'D://Panoptic_2017/train2017/000000484432.jpg': ['<start> A bunt cake sitting on a glaze cake plate with glazed being drizzled over it. <end>',
#               '<start> A large round cake rests on a glass plate. <end>',
#               '<start> Someone spooning a glaze over a bundt cake. <end>',
#               '<start> A person is spooning melted butter over a bundt cake.  <end>',
#               '<start> A person spooning a liquid over the top of a bunt cake that is one a glass serving plate. <end>'],
#              'D://Panoptic_2017/train2017/000000414156.jpg': ['<start> A kitchen with wooden counter tops and a stove top oven. <end>',
#               '<start> A small and clean home kitchen with wooden counters <end>',
#               '<start> Here is a nice and homey little kitchen arrangement <end>',
#               '<start> an image of kitchen setting with an island kitchen <end>',
#               '<start> a kitchen with plates a stove a sink and counter tops <end>'],
#              'D://Panoptic_2017/train2017/000000320703.jpg': ['<start> A narrow kitchen with a white stove top oven. <end>',
#               '<start> A long galley kitchen with cabinets on both sides <end>',
#               '<start> a long narrow kitchen with cups in the sink <end>',
#               '<start> A white and light gray kitchen with stove, sink, and refrigerator.  <end>',
#               '<start> an image of a kitchen setting with formica counter <end>'],
#              'D://Panoptic_2017/train2017/000000555686.jpg': ['<start> A woman posing and riding on a red motorcycle <end>',
#               '<start> A woman in leather pants posing on a red motorcycle. <end>',
#               '<start> A woman outside in front of a building posing on a motorcycle <end>',
#               '<start> A picture of a person on a motorcycle. <end>',
#               '<start> The woman is sitting on the motorcycle by the plants. <end>'],
#              'D://Panoptic_2017/train2017/000000253223.jpg': ['<start> a building with two towers and an air plane in the background <end>',
#               '<start> A jet airliner in flight over a religious structure. <end>',
#               '<start> A plane flying high over a historically built building. <end>',
#               '<start> a view of an old building with a plane flying in the background <end>',
#               '<start> The upper portion of an ornate stone church, with an airplane flying overhead <end>'],
#              'D://Panoptic_2017/train2017/000000579468.jpg': ['<start> A beautiful woman with a blue fro brushing her teeth with a giant toothbrush. <end>',
#               '<start> an image of a girl with a blue wig and a tootbrush <end>',
#               '<start> A young woman with blue hair uses an oversized toothbrush. <end>',
#               '<start> A woman with blue hair and a giant toothbrush <end>',
#               '<start> A woman with a blue wig brushes her teeth.  <end>'],
#              'D://Panoptic_2017/train2017/000000255248.jpg': ['<start> A cook sanding between two women inside of a kitchen. <end>',
#               '<start> A man in camo pointing at the ceiling <end>',
#               '<start> a guy in blue camo in a kitchen teaching girls how to cook <end>',
#               '<start> The soldier is talking to an attentive student. <end>',
#               '<start> three people in a kitchen area with a table with bowls <end>'],
#              'D://Panoptic_2017/train2017/000000456328.jpg': ['<start> A bathroom photo focusing on the toilet and the window. <end>',
#               '<start> A bathroom is shown in a dim lit setting. <end>',
#               '<start> A bathroom with a toilet and no toilet paper. <end>',
#               '<start> A small bathroom, toilet and sink with a large window. <end>',
#               '<start> A bathroom with toilet and a curtained window <end>'],
#              'D://Panoptic_2017/train2017/000000390241.jpg': ['<start> A white train car lays on its side in the dark while a man with a light is nearby. <end>',
#               '<start> on overturned bus on the side of the road  <end>',
#               '<start> A bus is tipped over on its side. <end>',
#               '<start> A bus tipped over on the side of the road <end>',
#               '<start> A picture of a bus that is turned over. <end>'],
#              'D://Panoptic_2017/train2017/000000564699.jpg': ['<start> A tiled bathroom altered to suit the needs of the handicapped. <end>',
#               '<start> a handicapped toilet with bars and a sink <end>',
#               '<start> This toilet is accessible to a handicapped person. <end>',
#               '<start> A toilet with extended help bars and a handle for lifting. <end>',
#               '<start> A small bathroom that appears to be handicapped accessory.  <end>'],
#              ...})

# %%
from PIL import Image

Image.open('D://Panoptic_2017/train2017/000000203564.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x1F207538B48>

# %%
image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)

# %%
# Select the first 6000 image_paths from the shuffled set.
# Approximately each image id has 5 captions associated with it, so that will 
# lead to 30,000 examples.
train_image_paths = image_paths[:6000]
print(len(train_image_paths))
# Out:
# 6000

# %%
train_captions = []
img_name_vector = []

for image_path in train_image_paths:
    caption_list = image_path_to_caption[image_path]
    train_captions.extend(caption_list)
    img_name_vector.extend([image_path] * len(caption_list))

# %%
len(img_name_vector)
# Out:
# 30017

# %%
print(train_captions[0])
Image.open(img_name_vector[0])
# Out:
# <start> a man and a woman hold up wine glasses <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x510 at 0x1F20758CF08>

# %%
img_name_vector[:8]
# Out:
# ['D://Panoptic_2017/train2017/000000140935.jpg',
#  'D://Panoptic_2017/train2017/000000140935.jpg',
#  'D://Panoptic_2017/train2017/000000140935.jpg',
#  'D://Panoptic_2017/train2017/000000140935.jpg',
#  'D://Panoptic_2017/train2017/000000140935.jpg',
#  'D://Panoptic_2017/train2017/000000422591.jpg',
#  'D://Panoptic_2017/train2017/000000422591.jpg',
#  'D://Panoptic_2017/train2017/000000422591.jpg']

# %%
train_captions[:8]
# Out:
# ['<start> a man and a woman hold up wine glasses <end>',
#  '<start> A man and woman holding up wine glasses and smiling in a wine-tasting room. <end>',
#  '<start> A man and a woman pose for a picture with their wine. <end>',
#  '<start> Man and woman standing in the kitchen holding wineglasses together.  <end>',
#  '<start> A man and a woman pose with glasses of wine. <end>',
#  '<start> A photographer talking a photo of a dog <end>',
#  '<start> The photographer is a taking a picture of a dog.  <end>',
#  '<start> A man taking a picture of his dog through a mirror. <end>']
